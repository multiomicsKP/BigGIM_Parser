# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/guangrong/Documents/GitHub_project/fastqpi_BigGIM/KGs/formated/pubchem_drug_to_disease_formatted.csv")

# %%
data_noNA = data.dropna()

# %%
data_noNA['subject_id'] = data_noNA['subject_id'].astype(int)
# Out:
# /var/folders/w1/p1v0w3j165ggfdk4xpn0tzgh0000gp/T/ipykernel_60681/3176564720.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_noNA['subject_id'] = data_noNA['subject_id'].astype(int)

# %%
set(data_noNA['object_name'])
# Out:
# {'BLAD',
#  'BRCA',
#  'Basal Cell Carcinoma',
#  'Bone Cancer',
#  'Cancer',
#  'Cholangiocarcinoma',
#  'Gastrointestinal Stromal Tumors',
#  'HNSCC',
#  'Heart failure',
#  'Hutchinson-Gilford Progeria Syndrome',
#  'Kidney (Renal Cell) Cancer',
#  'Melanoma',
#  'NSCLC',
#  'Non-Hodgkin Lymphoma',
#  'Ovarian',
#  'Prostate cancer',
#  'SCLC',
#  'Soft Tissue Sarcoma',
#  'Thyroid Cancer',
#  'acute lymphoblastic leukemia',
#  'acute myelogenous leukemia',
#  'asthma',
#  'chronic myelogenous leukemia',
#  'chronic obstructive pulmonary disease',
#  'crohn disease',
#  'hodgkins lymphoma',
#  'ovarian cancer',
#  'plasma cell myeloma',
#  'sarcoma',
#  'small lymphocytic lymphoma',
#  'urgency urinary incontinence'}

# %%
data_noNA.loc[data_noNA['object_name'] == "chronic myelogenous leukemia" ]
# Out:
#       subject_id               subject_name subject_category  \
# 32          5291                   Imatinib             drug
# 33          5291                   Imatinib             drug
# 34          5291                   Imatinib             drug
# 35          5291                   Imatinib             drug
# 36          5291                   Imatinib             drug
# 37          5291                   Imatinib             drug
# 38          5291                   Imatinib             drug
# 39          5291                   Imatinib             drug
# 40          5291                   Imatinib             drug
# 1226        2478                   Busulfan             drug
# 1289      285033  Omacetaxine mepesuccinate             drug
# 1304      285033  Omacetaxine mepesuccinate             drug
#
#      subject_id_prefixes   object_id                   object_name  \
# 32      Pubchem.compound  HP:0005506  chronic myelogenous leukemia
# ...

# %%
data_file = open("/Users/guangrong/Documents/GitHub_project/fastqpi_BigGIM/KGs/Drug_Target/FDA_approved_drugs.csv")

# %%
for
