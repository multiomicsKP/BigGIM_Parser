# %%
# Query BigGIM-DrugResponse KP

# %%
import requests
import json
import os
#BigGIM_URL = "https://api.bte.ncats.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"
#BigGIM_URL = "https://api.bte.ncats.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"


BigGIM_URL_dev = "https://api.bte.ncats.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"
BigGIM_URL_ci = "https://bte.ci.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"
BigGIM_URL_test = "https://bte.test.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query" #TRAPI 1.4 endpoint
BigGIM_URL = "https://bte.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"  #TRAPI 1.3 endpoint

#https://arax.test.transltr.io/ #TRAPI1.4
#https://arax.transltr.io/ #TRAPI1.3

#Specify url in the ARAX with https://bte.test.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31 or https://bte.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31

# SmartAPI regstration: https://smart-api.info/registry?q=multiomics

# %%
#Example: which drugs shows sensitivity with KRAS (NCBIGene:3845) altered?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids":["NCBIGene:3845"],
 
                },
                "n1": {
                    "categories":["biolink:Protein", "biolink:Gene"],

               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:physically_interacts_with"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL,json=query_json)
result = response.json()["message"]

# %%
result['knowledge_graph']
# Out:
# {'nodes': {'NCBIGene:1915': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'EEF1A1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:1915',
#       'ENSEMBL:ENSG00000156508',
#       'HGNC:3189',
#       'OMIM:130590',
#       'UMLS:C1414270',
#       'UniProtKB:P68104',
#       'PR:P68104',
#       'ENSEMBL:ENSP00000330054',
#       'ENSEMBL:ENSP00000330054.2',
#       'ENSEMBL:ENSP00000339053',
#       'ENSEMBL:ENSP00000339053.4',
#       'ENSEMBL:ENSP00000339063',
#       'ENSEMBL:ENSP00000339063.7',
#       'ENSEMBL:ENSP00000348651',
#       'ENSEMBL:ENSP00000348651.3',
#       'ENSEMBL:ENSP00000392366',
#       'ENSEMBL:ENSP00000392366.2',
#       'ENSEMBL:ENSP00000479055',
#       'ENSEMBL:ENSP00000479055.2',
#       'ENSEMBL:ENSP00000503192',
#       'ENSEMBL:ENSP00000503192.1',
#       'ENSEMBL:ENSP00000503249',
#       'ENSEMBL:ENSP00000503249.1',
#       'ENSEMBL:ENSP00000503823',
#       'ENSEMBL:ENSP00000503823.1',
#       'ENSEMBL:ENSP00000504335',
#       'ENSEMBL:ENSP00000504335.1',
#       'UMLS:C0300140',
#       'UniProtKB:Q6IPS9']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['EEF1A1',
#       'EEF1A1 gene',
#       'EF1A1_HUMAN Elongation factor 1-alpha 1 (sprot)',
#       'elongation factor 1-alpha 1 (human)',
#       'EEF1A1 protein, human',
#       'Q6IPS9_HUMAN Elongation factor 1-alpha (trembl)']}]},
#   'NCBIGene:3845': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'KRAS',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3845',
#       'ENSEMBL:ENSG00000133703',
#       'HGNC:6407',
#       'OMIM:190070',
#       'UMLS:C1537502',
#       'UniProtKB:A0A024RAV5',
#       'UniProtKB:I1SRC5',
#       'UniProtKB:L7RSL8',
#       'UniProtKB:P01116',
#       'PR:P01116',
#       'UMLS:C0763464']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['KRAS',
#       'KRAS gene',
#       'A0A024RAV5_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog, isoform CRA_b (trembl)',
#       'I1SRC5_HUMAN UBE2L3/KRAS fusion protein (trembl)',
#       'L7RSL8_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog (trembl)',
#       'RASK_HUMAN GTPase KRas (sprot)',
#       'GTPase KRas (human)',
#       'KRAS protein, human']}]},
#   'NCBIGene:6125': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPL5',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6125',
#       'ENSEMBL:ENSG00000122406',
#       'HGNC:10360',
#       'OMIM:603634',
#       'UMLS:C1419683',
#       'UniProtKB:A2RUM7',
#       'UniProtKB:P46777',
#       'PR:P46777',
#       'ENSEMBL:ENSP00000359345',
#       'ENSEMBL:ENSP00000359345.2',
#       'UMLS:C2933718']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPL5',
#       'RPL5 gene',
#       'A2RUM7_HUMAN Ribosomal protein L5 (trembl)',
#       'RL5_HUMAN 60S ribosomal protein L5 (sprot)',
#       '60S ribosomal protein L5 (human)',
#       'ribosomal protein L5, human']}]},
#   'NCBIGene:5690': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PSMB2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5690',
#       'ENSEMBL:ENSG00000126067',
#       'HGNC:9539',
#       'OMIM:602175',
#       'UMLS:C1419012',
#       'UniProtKB:A0A087WVV1',
#       'ENSEMBL:ENSP00000479706',
#       'ENSEMBL:ENSP00000479706.1',
#       'UniProtKB:A0A140VJS6',
#       'UniProtKB:B7Z478',
#       'UniProtKB:P49721',
#       'PR:P49721',
#       'ENSEMBL:ENSP00000362334',
#       'ENSEMBL:ENSP00000362334.3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PSMB2',
#       'PSMB2 gene',
#       'A0A087WVV1_HUMAN Proteasome subunit beta type-2 (trembl)',
#       'A0A140VJS6_HUMAN Proteasome subunit beta (trembl)',
#       'B7Z478_HUMAN Proteasome subunit beta (trembl)',
#       'PSB2_HUMAN Proteasome subunit beta type-2 (sprot)',
#       'proteasome subunit beta type-2 (human)']}]},
#   'NCBIGene:26227': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PHGDH',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:26227',
#       'ENSEMBL:ENSG00000092621',
#       'HGNC:8923',
#       'OMIM:606879',
#       'UMLS:C1418531',
#       'UniProtKB:O43175',
#       'PR:O43175',
#       'ENSEMBL:ENSP00000493175',
#       'ENSEMBL:ENSP00000493175.1',
#       'ENSEMBL:ENSP00000493382',
#       'ENSEMBL:ENSP00000493382.1',
#       'UMLS:C4048261']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PHGDH',
#       'PHGDH gene',
#       'SERA_HUMAN D-3-phosphoglycerate dehydrogenase (sprot)',
#       'D-3-phosphoglycerate dehydrogenase (human)',
#       'D-3-Phosphoglycerate Dehydrogenase, human']}]},
#   'NCBIGene:1982': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'EIF4G2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:1982',
#       'ENSEMBL:ENSG00000110321',
#       'HGNC:3297',
#       'OMIM:602325',
#       'UMLS:C1414357',
#       'UniProtKB:P78344',
#       'PR:P78344',
#       'UniProtKB:Q2TU89']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['EIF4G2',
#       'EIF4G2 gene',
#       'IF4G2_HUMAN Eukaryotic translation initiation factor 4 gamma 2 (sprot)',
#       'eukaryotic translation initiation factor 4 gamma 2 (human)',
#       'Q2TU89_HUMAN Aging-associated protein 1 (trembl)']}]},
#   'NCBIGene:7520': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'XRCC5',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7520',
#       'ENSEMBL:ENSG00000079246',
#       'HGNC:12833',
#       'OMIM:194364',
#       'UMLS:C1337034',
#       'UniProtKB:P13010',
#       'PR:P13010',
#       'ENSEMBL:ENSP00000375977',
#       'ENSEMBL:ENSP00000375977.2',
#       'ENSEMBL:ENSP00000375978',
#       'ENSEMBL:ENSP00000375978.3',
#       'UMLS:C0064435']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['XRCC5',
#       'XRCC5 gene',
#       'XRCC5_HUMAN X-ray repair cross-complementing protein 5 (sprot)',
#       'X-ray repair cross-complementing protein 5 (human)',
#       'XRCC5 protein, human']}]},
#   'NCBIGene:7525': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'YES1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7525',
#       'ENSEMBL:ENSG00000176105',
#       'HGNC:12841',
#       'OMIM:164880',
#       'UMLS:C0919479',
#       'UniProtKB:P07947',
#       'PR:P07947',
#       'ENSEMBL:ENSP00000324740',
#       'ENSEMBL:ENSP00000324740.4',
#       'ENSEMBL:ENSP00000462468',
#       'ENSEMBL:ENSP00000462468.1',
#       'UMLS:C1452531']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YES1',
#       'YES1 gene',
#       'YES_HUMAN Tyrosine-protein kinase Yes (sprot)',
#       'tyrosine-protein kinase Yes (human)',
#       'YES1 protein, human']}]},
#   'NCBIGene:3831': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'KLC1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3831',
#       'ENSEMBL:ENSG00000126214',
#       'HGNC:6387',
#       'OMIM:600025',
#       'UMLS:C1416692',
#       'UniProtKB:Q07866',
#       'PR:Q07866',
#       'UMLS:C1505128',
#       'UniProtKB:Q7RTQ2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['KLC1',
#       'KLC1 gene',
#       'KLC1_HUMAN Kinesin light chain 1 (sprot)',
#       'kinesin light chain 1 (human)',
#       'KNS2 protein, human',
#       'Q7RTQ2_HUMAN Kinesin light chain (trembl)']}]},
#   'NCBIGene:6203': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPS9',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6203',
#       'ENSEMBL:ENSG00000170889',
#       'HGNC:10442',
#       'OMIM:603631',
#       'UMLS:C1419753',
#       'UniProtKB:A0A024R4M0',
#       'UniProtKB:A8MXK4',
#       'ENSEMBL:ENSP00000375631',
#       'ENSEMBL:ENSP00000375631.3',
#       'ENSEMBL:ENSP00000481941',
#       'ENSEMBL:ENSP00000481941.1',
#       'UniProtKB:P46781',
#       'PR:P46781',
#       'ENSEMBL:ENSP00000302896',
#       'ENSEMBL:ENSP00000302896.4',
#       'ENSEMBL:ENSP00000375632',
#       'ENSEMBL:ENSP00000375632.1',
#       'ENSEMBL:ENSP00000375633',
#       'ENSEMBL:ENSP00000375633.2',
#       'ENSEMBL:ENSP00000478449',
#       'ENSEMBL:ENSP00000478449.1',
#       'ENSEMBL:ENSP00000479917',
#       'ENSEMBL:ENSP00000479917.1',
#       'ENSEMBL:ENSP00000480135',
#       'ENSEMBL:ENSP00000480135.1',
#       'ENSEMBL:ENSP00000480662',
#       'ENSEMBL:ENSP00000480662.1',
#       'ENSEMBL:ENSP00000481194',
#       'ENSEMBL:ENSP00000481194.1',
#       'ENSEMBL:ENSP00000481553',
#       'ENSEMBL:ENSP00000481553.1',
#       'ENSEMBL:ENSP00000481655',
#       'ENSEMBL:ENSP00000481655.1',
#       'ENSEMBL:ENSP00000481764',
#       'ENSEMBL:ENSP00000481764.1',
#       'ENSEMBL:ENSP00000481822',
#       'ENSEMBL:ENSP00000481822.1',
#       'ENSEMBL:ENSP00000482023',
#       'ENSEMBL:ENSP00000482023.1',
#       'ENSEMBL:ENSP00000482274',
#       'ENSEMBL:ENSP00000482274.1',
#       'ENSEMBL:ENSP00000482338',
#       'ENSEMBL:ENSP00000482338.1',
#       'ENSEMBL:ENSP00000482475',
#       'ENSEMBL:ENSP00000482475.1',
#       'ENSEMBL:ENSP00000483179',
#       'ENSEMBL:ENSP00000483179.1',
#       'ENSEMBL:ENSP00000484394',
#       'ENSEMBL:ENSP00000484394.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPS9',
#       'RPS9 gene',
#       'A0A024R4M0_HUMAN 40S ribosomal protein S9 (trembl)',
#       'A8MXK4_HUMAN 40S ribosomal protein S9 (trembl)',
#       'RS9_HUMAN 40S ribosomal protein S9 (sprot)',
#       '40S ribosomal protein S9 (human)']}]},
#   'NCBIGene:1968': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'EIF2S3',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:1968',
#       'ENSEMBL:ENSG00000130741',
#       'HGNC:3267',
#       'OMIM:300161',
#       'UMLS:C1414336',
#       'UniProtKB:P41091',
#       'PR:P41091',
#       'ENSEMBL:ENSP00000253039',
#       'ENSEMBL:ENSP00000253039.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['EIF2S3',
#       'EIF2S3 gene',
#       'IF2G_HUMAN Eukaryotic translation initiation factor 2 subunit 3 (sprot)',
#       'eukaryotic translation initiation factor 2 subunit 3 (human)']}]},
#   'NCBIGene:10413': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'YAP1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10413',
#       'ENSEMBL:ENSG00000137693',
#       'HGNC:16262',
#       'OMIM:606608',
#       'UMLS:C1424135',
#       'UniProtKB:A0A024R3E4',
#       'UniProtKB:K0KVU2',
#       'UniProtKB:P46937',
#       'PR:P46937',
#       'UMLS:C1318127',
#       'UniProtKB:Q86T74']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YAP1',
#       'YAP1 gene',
#       'A0A024R3E4_HUMAN Yes-associated protein 1, 65kDa, isoform CRA_b (trembl)',
#       'K0KVU2_HUMAN Yes-associated protein isoform 9 (Fragment) (trembl)',
#       'YAP1_HUMAN Transcriptional coactivator YAP1 (sprot)',
#       'transcriptional coactivator YAP1 (human)',
#       'YAP1 protein, human',
#       'Q86T74_HUMAN Uncharacterized protein DKFZp451O0517 (Fragment) (trembl)']}]},
#   'NCBIGene:1739': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'DLG1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:1739',
#       'ENSEMBL:ENSG00000075711',
#       'HGNC:2900',
#       'OMIM:601014',
#       'UMLS:C1333225',
#       'UniProtKB:A0A0C4DFT3',
#       'ENSEMBL:ENSP00000499269',
#       'ENSEMBL:ENSP00000499269.1',
#       'ENSEMBL:ENSP00000499440',
#       'ENSEMBL:ENSP00000499440.1',
#       'ENSEMBL:ENSP00000499507',
#       'ENSEMBL:ENSP00000499507.1',
#       'ENSEMBL:ENSP00000499584',
#       'ENSEMBL:ENSP00000499584.1',
#       'UniProtKB:A0A590UJ08',
#       'ENSEMBL:ENSP00000499229',
#       'ENSEMBL:ENSP00000499229.1',
#       'UniProtKB:B4DF78',
#       'UniProtKB:Q12959',
#       'PR:Q12959',
#       'UMLS:C1442790']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['DLG1',
#       'DLG1 gene',
#       'A0A0C4DFT3_HUMAN Disks large homolog 1 (trembl)',
#       'A0A590UJ08_HUMAN Disks large homolog 1 (trembl)',
#       'B4DF78_HUMAN cDNA FLJ50462, highly similar to Disks large homolog 1 (trembl)',
#       'DLG1_HUMAN Disks large homolog 1 (sprot)',
#       'disks large homolog 1 (human)',
#       'DLG1 protein, human']}]},
#   'NCBIGene:4008': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'LMO7',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:4008',
#       'ENSEMBL:ENSG00000136153',
#       'HGNC:6646',
#       'OMIM:604362',
#       'UMLS:C1416885',
#       'UniProtKB:A0A0A0MTE2',
#       'ENSEMBL:ENSP00000433352',
#       'ENSEMBL:ENSP00000433352.1',
#       'UniProtKB:E9PMT2',
#       'ENSEMBL:ENSP00000317802',
#       'ENSEMBL:ENSP00000317802.8',
#       'UniProtKB:F8J2B5',
#       'UniProtKB:F8WD26',
#       'ENSEMBL:ENSP00000366757',
#       'ENSEMBL:ENSP00000366757.4',
#       'UniProtKB:Q8WWI1',
#       'PR:Q8WWI1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['LMO7',
#       'LMO7 gene',
#       'A0A0A0MTE2_HUMAN LIM domain only protein 7 (trembl)',
#       'E9PMT2_HUMAN LIM domain only protein 7 (trembl)',
#       'F8J2B5_HUMAN LIM domain only 7 protein (trembl)',
#       'F8WD26_HUMAN LIM domain only protein 7 (trembl)',
#       'LMO7_HUMAN LIM domain only protein 7 (sprot)',
#       'LIM domain only protein 7 (human)']}]},
#   'NCBIGene:6208': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPS14',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6208',
#       'ENSEMBL:ENSG00000164587',
#       'HGNC:10387',
#       'OMIM:130620',
#       'UMLS:C1419703',
#       'UniProtKB:P62263',
#       'PR:P62263',
#       'ENSEMBL:ENSP00000311028',
#       'ENSEMBL:ENSP00000311028.5',
#       'ENSEMBL:ENSP00000385425',
#       'ENSEMBL:ENSP00000385425.1',
#       'ENSEMBL:ENSP00000385958',
#       'ENSEMBL:ENSP00000385958.3',
#       'ENSEMBL:ENSP00000428509',
#       'ENSEMBL:ENSP00000428509.1',
#       'UMLS:C3539647']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPS14',
#       'RPS14 gene',
#       'RS14_HUMAN 40S ribosomal protein S14 (sprot)',
#       '40S ribosomal protein S14 (human)',
#       '40S Ribosomal Protein S14, human']}]},
#   'NCBIGene:4116': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'MAGOH',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:4116',
#       'ENSEMBL:ENSG00000162385',
#       'HGNC:6815',
#       'OMIM:602603',
#       'UMLS:C1416987',
#       'UniProtKB:P61326',
#       'PR:P61326']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MAGOH',
#       'MAGOH gene',
#       'MGN_HUMAN Protein mago nashi homolog (sprot)',
#       'protein mago nashi homolog (human)']}]},
#   'NCBIGene:2079': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'ERH',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2079',
#       'ENSEMBL:ENSG00000100632',
#       'HGNC:3447',
#       'OMIM:601191',
#       'UMLS:C1414443',
#       'UniProtKB:A0A024R6D4',
#       'UniProtKB:P84090',
#       'PR:P84090',
#       'ENSEMBL:ENSP00000451080',
#       'ENSEMBL:ENSP00000451080.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ERH',
#       'ERH gene',
#       'A0A024R6D4_HUMAN Enhancer of rudimentary homolog (trembl)',
#       'ERH_HUMAN Enhancer of rudimentary homolog (sprot)',
#       'enhancer of rudimentary homolog (human)']}]},
#   'NCBIGene:6134': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPL10',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6134',
#       'ENSEMBL:ENSG00000147403',
#       'HGNC:10298',
#       'OMIM:312173',
#       'UMLS:C1335635',
#       'UniProtKB:P27635',
#       'PR:P27635',
#       'ENSEMBL:ENSP00000341730',
#       'ENSEMBL:ENSP00000341730.4',
#       'ENSEMBL:ENSP00000358832',
#       'ENSEMBL:ENSP00000358832.2',
#       'UMLS:C1609289',
#       'UniProtKB:X5D2T3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPL10',
#       'RPL10 gene',
#       'RL10_HUMAN 60S ribosomal protein L10 (sprot)',
#       '60S ribosomal protein L10 (human)',
#       'RPL10 protein, human',
#       'X5D2T3_HUMAN Ribosomal protein L10 isoform A (Fragment) (trembl)']}]},
#   'NCBIGene:6224': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPS20',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6224',
#       'ENSEMBL:ENSG00000008988',
#       'HGNC:10405',
#       'OMIM:603682',
#       'UMLS:C1419719',
#       'UniProtKB:P60866',
#       'PR:P60866',
#       'UMLS:C1615592']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPS20',
#       'RPS20 gene',
#       'RS20_HUMAN 40S ribosomal protein S20 (sprot)',
#       '40S ribosomal protein S20 (human)',
#       'RPS20 protein, human']}]},
#   'NCBIGene:6147': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPL23A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6147',
#       'ENSEMBL:ENSG00000198242',
#       'HGNC:10317',
#       'OMIM:602326',
#       'UMLS:C1419641',
#       'UniProtKB:P62750',
#       'PR:P62750',
#       'ENSEMBL:ENSP00000389103',
#       'ENSEMBL:ENSP00000389103.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPL23A',
#       'RPL23A gene',
#       'RL23A_HUMAN 60S ribosomal protein L23a (sprot)',
#       '60S ribosomal protein L23a (human)']}]},
#   'NCBIGene:375': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'ARF1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:375',
#       'ENSEMBL:ENSG00000143761',
#       'HGNC:652',
#       'OMIM:103180',
#       'UMLS:C1412504',
#       'UniProtKB:A0A024R3Q0',
#       'UniProtKB:P84077',
#       'PR:P84077',
#       'ENSEMBL:ENSP00000272102',
#       'ENSEMBL:ENSP00000272102.5',
#       'ENSEMBL:ENSP00000440005',
#       'ENSEMBL:ENSP00000440005.1',
#       'ENSEMBL:ENSP00000442980',
#       'ENSEMBL:ENSP00000442980.1',
#       'UMLS:C4552603']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ARF1',
#       'ARF1 gene',
#       'A0A024R3Q0_HUMAN ADP-ribosylation factor (trembl)',
#       'ARF1_HUMAN ADP-ribosylation factor 1 (sprot)',
#       'ADP-ribosylation factor 1 (human)',
#       'ADP-Ribosylation Factor 1, human']}]},
#   'NCBIGene:9532': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'BAG2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9532',
#       'ENSEMBL:ENSG00000112208',
#       'HGNC:938',
#       'OMIM:603882',
#       'UMLS:C1412730',
#       'UniProtKB:O95816',
#       'PR:O95816']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['BAG2',
#       'BAG2 gene',
#       'BAG2_HUMAN BAG family molecular chaperone regulator 2 (sprot)',
#       'BAG family molecular chaperone regulator 2 (human)']}]},
#   'NCBIGene:6129': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPL7',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6129',
#       'ENSEMBL:ENSG00000147604',
#       'HGNC:10363',
#       'OMIM:604166',
#       'UMLS:C1419686',
#       'UniProtKB:P18124',
#       'PR:P18124',
#       'ENSEMBL:ENSP00000339795',
#       'ENSEMBL:ENSP00000339795.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPL7',
#       'RPL7 gene',
#       'RL7_HUMAN 60S ribosomal protein L7 (sprot)',
#       '60S ribosomal protein L7 (human)']}]},
#   'NCBIGene:22800': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RRAS2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:22800',
#       'ENSEMBL:ENSG00000133818',
#       'HGNC:17271',
#       'OMIM:600098',
#       'UMLS:C1335647',
#       'UniProtKB:P62070',
#       'PR:P62070',
#       'UMLS:C1447284']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RRAS2',
#       'RRAS2 gene',
#       'RRAS2_HUMAN Ras-related protein R-Ras2 (sprot)',
#       'Ras-related protein R-Ras2 (human)',
#       'RRAS2 protein, human']}]},
#   'NCBIGene:5894': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RAF1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5894',
#       'ENSEMBL:ENSG00000132155',
#       'HGNC:9829',
#       'OMIM:164760',
#       'UMLS:C0812215',
#       'UniProtKB:A0A0S2Z4L5',
#       'ENSEMBL:ENSP00000508794',
#       'ENSEMBL:ENSP00000508794.1',
#       'ENSEMBL:ENSP00000509612',
#       'ENSEMBL:ENSP00000509612.1',
#       'ENSEMBL:ENSP00000509669',
#       'ENSEMBL:ENSP00000509669.1',
#       'UniProtKB:L7RRS6',
#       'UniProtKB:P04049',
#       'PR:P04049',
#       'UMLS:C4706023']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAF1',
#       'RAF1 gene',
#       'A0A0S2Z4L5_HUMAN Non-specific serine/threonine protein kinase (Fragment) (trembl)',
#       'L7RRS6_HUMAN Non-specific serine/threonine protein kinase (trembl)',
#       'RAF1_HUMAN RAF proto-oncogene serine/threonine-protein kinase (sprot)',
#       'RAF proto-oncogene serine/threonine-protein kinase (human)',
#       'RAF1 protein, human']}]},
#   'NCBIGene:3183': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'HNRNPC',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3183',
#       'ENSEMBL:ENSG00000092199',
#       'HGNC:5035',
#       'OMIM:164020',
#       'UMLS:C1415637',
#       'UniProtKB:P07910',
#       'PR:P07910']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['HNRNPC',
#       'HNRNPC gene',
#       'HNRPC_HUMAN Heterogeneous nuclear ribonucleoproteins C1/C2 (sprot)',
#       'heterogeneous nuclear ribonucleoproteins C1/C2 (human)']}]},
#   'NCBIGene:6165': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPL35A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6165',
#       'ENSEMBL:ENSG00000182899',
#       'HGNC:10345',
#       'OMIM:180468',
#       'UMLS:C1419668',
#       'UniProtKB:P18077',
#       'PR:P18077',
#       'ENSEMBL:ENSP00000393393',
#       'ENSEMBL:ENSP00000393393.1',
#       'ENSEMBL:ENSP00000495672',
#       'ENSEMBL:ENSP00000495672.1',
#       'UMLS:C1454100']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPL35A',
#       'RPL35A gene',
#       'RL35A_HUMAN 60S ribosomal protein L35a (sprot)',
#       '60S ribosomal protein L35a (human)',
#       '60S Ribosomal Protein L35a, Human']}]},
#   'NCBIGene:55832': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'CAND1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:55832',
#       'ENSEMBL:ENSG00000111530',
#       'HGNC:30688',
#       'OMIM:607727',
#       'UMLS:C1824525',
#       'UniProtKB:Q86VP6',
#       'PR:Q86VP6']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['CAND1',
#       'CAND1 gene',
#       'CAND1_HUMAN Cullin-associated NEDD8-dissociated protein 1 (sprot)',
#       'cullin-associated NEDD8-dissociated protein 1 (human)']}]},
#   'NCBIGene:3312': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'HSPA8',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3312',
#       'ENSEMBL:ENSG00000109971',
#       'HGNC:5241',
#       'OMIM:600816',
#       'UMLS:C1415764',
#       'UniProtKB:P11142',
#       'PR:P11142',
#       'UniProtKB:Q53HF2',
#       'UniProtKB:V9HW22']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['HSPA8',
#       'HSPA8 gene',
#       'HSP7C_HUMAN Heat shock cognate 71 kDa protein (sprot)',
#       'heat shock cognate 71 kDa protein (human)',
#       'Q53HF2_HUMAN Heat shock 70kDa protein 8 isoform 2 variant (Fragment) (trembl)',
#       'V9HW22_HUMAN Epididymis luminal protein 33 (trembl)']}]},
#   'NCBIGene:10236': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'HNRNPR',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10236',
#       'ENSEMBL:ENSG00000125944',
#       'HGNC:5047',
#       'OMIM:607201',
#       'UMLS:C1415648',
#       'UniProtKB:B4DMB1',
#       'UniProtKB:B4DMD1',
#       'UniProtKB:B4DT28',
#       'ENSEMBL:ENSP00000475760',
#       'ENSEMBL:ENSP00000475760.1',
#       'ENSEMBL:ENSP00000489386',
#       'ENSEMBL:ENSP00000489386.1',
#       'UniProtKB:O43390',
#       'PR:O43390',
#       'UniProtKB:Q0VGD6',
#       'UniProtKB:Q6MZS5']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['HNRNPR',
#       'HNRNPR gene',
#       'B4DMB1_HUMAN cDNA FLJ53358, highly similar to Heterogeneous nuclear ribonucleoprotein R (trembl)',
#       'B4DMD1_HUMAN cDNA FLJ53360, highly similar to Heterogeneous nuclear ribonucleoprotein R (trembl)',
#       'B4DT28_HUMAN Heterogeneous nuclear ribonucleoprotein R (trembl)',
#       'HNRPR_HUMAN Heterogeneous nuclear ribonucleoprotein R (sprot)',
#       'heterogeneous nuclear ribonucleoprotein R (human)',
#       'Q0VGD6_HUMAN HNRPR protein (Fragment) (trembl)',
#       'Q6MZS5_HUMAN Uncharacterized protein DKFZp686A13234 (Fragment) (trembl)']}]},
#   'NCBIGene:2547': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'XRCC6',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2547',
#       'ENSEMBL:ENSG00000196419',
#       'HGNC:4055',
#       'OMIM:152690',
#       'UMLS:C1823878',
#       'UniProtKB:A0A024R1N4',
#       'UniProtKB:B1AHC9',
#       'ENSEMBL:ENSP00000384082',
#       'ENSEMBL:ENSP00000384082.1',
#       'ENSEMBL:ENSP00000403679',
#       'ENSEMBL:ENSP00000403679.3',
#       'UniProtKB:B4DE32',
#       'UniProtKB:B4E356',
#       'UniProtKB:P12956',
#       'PR:P12956',
#       'UMLS:C4308049']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['XRCC6',
#       'XRCC6 gene',
#       'A0A024R1N4_HUMAN X-ray repair complementing defective repair in Chinese hamster cells 6 (Ku autoantigen, 70kDa), isoform CRA_a (trembl)',
#       'B1AHC9_HUMAN X-ray repair cross-complementing protein 6 (trembl)',
#       'B4DE32_HUMAN cDNA FLJ53970, highly similar to ATP-dependent DNA helicase 2 subunit 1 (EC3.6.1.-) (trembl)',
#       'B4E356_HUMAN cDNA FLJ54993, highly similar to ATP-dependent DNA helicase 2 subunit 1 (trembl)',
#       'XRCC6_HUMAN X-ray repair cross-complementing protein 6 (sprot)',
#       'X-ray repair cross-complementing protein 6 (human)',
#       'XRCC6 protein, human']}]},
#   'NCBIGene:2810': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SFN',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2810',
#       'ENSEMBL:ENSG00000175793',
#       'HGNC:10773',
#       'OMIM:601290',
#       'UMLS:C1335813',
#       'UniProtKB:P31947',
#       'PR:P31947',
#       'UMLS:C0972212']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SFN',
#       'SFN gene',
#       '1433S_HUMAN 14-3-3 protein sigma (sprot)',
#       '14-3-3 protein sigma (human)',
#       'SFN protein, human']}]},
#   'NCBIGene:6286': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'S100P',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6286',
#       'ENSEMBL:ENSG00000163993',
#       'HGNC:10504',
#       'OMIM:600614',
#       'UMLS:C1335799',
#       'UniProtKB:P25815',
#       'PR:P25815',
#       'ENSEMBL:ENSP00000296370',
#       'ENSEMBL:ENSP00000296370.3',
#       'UMLS:C1447472']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['S100P',
#       'S100P gene',
#       'S100P_HUMAN Protein S100-P (sprot)',
#       'protein S100-P (human)',
#       'S100P protein, human']}]},
#   'NCBIGene:3185': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'HNRNPF',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3185',
#       'ENSEMBL:ENSG00000169813',
#       'HGNC:5039',
#       'OMIM:601037',
#       'UMLS:C1415641',
#       'UniProtKB:A0A024R7T3',
#       'UniProtKB:P52597',
#       'PR:P52597',
#       'ENSEMBL:ENSP00000338477',
#       'ENSEMBL:ENSP00000338477.3',
#       'ENSEMBL:ENSP00000348345',
#       'ENSEMBL:ENSP00000348345.3',
#       'ENSEMBL:ENSP00000349573',
#       'ENSEMBL:ENSP00000349573.4',
#       'ENSEMBL:ENSP00000400433',
#       'ENSEMBL:ENSP00000400433.2',
#       'ENSEMBL:ENSP00000438061',
#       'ENSEMBL:ENSP00000438061.1',
#       'ENSEMBL:ENSP00000507787',
#       'ENSEMBL:ENSP00000507787.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['HNRNPF',
#       'HNRNPF gene',
#       'A0A024R7T3_HUMAN Heterogeneous nuclear ribonucleoprotein F, isoform CRA_a (trembl)',
#       'HNRPF_HUMAN Heterogeneous nuclear ribonucleoprotein F (sprot)',
#       'heterogeneous nuclear ribonucleoprotein F (human)']}]},
#   'NCBIGene:6154': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPL26',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6154',
#       'ENSEMBL:ENSG00000161970',
#       'HGNC:10327',
#       'OMIM:603704',
#       'UMLS:C1419651',
#       'UniProtKB:P61254',
#       'PR:P61254',
#       'ENSEMBL:ENSP00000462322',
#       'ENSEMBL:ENSP00000462322.1',
#       'ENSEMBL:ENSP00000463470',
#       'ENSEMBL:ENSP00000463470.1',
#       'ENSEMBL:ENSP00000463784',
#       'ENSEMBL:ENSP00000463784.1',
#       'ENSEMBL:ENSP00000498177',
#       'ENSEMBL:ENSP00000498177.1',
#       'UMLS:C5445011']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPL26',
#       'RPL26 gene',
#       'RL26_HUMAN 60S ribosomal protein L26 (sprot)',
#       '60S ribosomal protein L26 (human)',
#       '60S Ribosomal Protein L26, Human']}]},
#   'NCBIGene:22948': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'CCT5',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:22948',
#       'ENSEMBL:ENSG00000150753',
#       'HGNC:1618',
#       'OMIM:610150',
#       'UMLS:C1413197',
#       'UniProtKB:B4DDU6',
#       'UniProtKB:B4DX08',
#       'UniProtKB:B4DYC8',
#       'UniProtKB:B7ZAR1',
#       'ENSEMBL:ENSP00000427297',
#       'ENSEMBL:ENSP00000427297.1',
#       'UniProtKB:E7ENZ3',
#       'ENSEMBL:ENSP00000426923',
#       'ENSEMBL:ENSP00000426923.1',
#       'UniProtKB:E9PCA1',
#       'ENSEMBL:ENSP00000423318',
#       'ENSEMBL:ENSP00000423318.1',
#       'UniProtKB:P48643',
#       'PR:P48643',
#       'UniProtKB:V9HW37']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['CCT5',
#       'CCT5 gene',
#       'B4DDU6_HUMAN T-complex protein 1 subunit epsilon (trembl)',
#       'B4DX08_HUMAN T-complex protein 1 subunit epsilon (trembl)',
#       'B4DYC8_HUMAN cDNA FLJ52361, highly similar to T-complex protein 1 subunit epsilon (trembl)',
#       'B7ZAR1_HUMAN T-complex protein 1 subunit epsilon (trembl)',
#       'E7ENZ3_HUMAN T-complex protein 1 subunit epsilon (trembl)',
#       'E9PCA1_HUMAN T-complex protein 1 subunit epsilon (trembl)',
#       'TCPE_HUMAN T-complex protein 1 subunit epsilon (sprot)',
#       'T-complex protein 1 subunit epsilon (human)',
#       'V9HW37_HUMAN T-complex protein 1 subunit epsilon (trembl)']}]},
#   'NCBIGene:6733': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SRPK2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6733',
#       'ENSEMBL:ENSG00000135250',
#       'HGNC:11306',
#       'OMIM:602980',
#       'UMLS:C1420413',
#       'UniProtKB:A0A024R704',
#       'UniProtKB:P78362',
#       'PR:P78362']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SRPK2',
#       'SRPK2 gene',
#       'A0A024R704_HUMAN SFRS protein kinase 2, isoform CRA_b (trembl)',
#       'SRPK2_HUMAN SRSF protein kinase 2 (sprot)',
#       'SRSF protein kinase 2 (human)']}]},
#   'NCBIGene:8125': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'ANP32A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8125',
#       'ENSEMBL:ENSG00000140350',
#       'HGNC:13233',
#       'OMIM:600832',
#       'UMLS:C1421894',
#       'UniProtKB:A0A384P5U2',
#       'UniProtKB:P39687',
#       'PR:P39687',
#       'ENSEMBL:ENSP00000417864',
#       'ENSEMBL:ENSP00000417864.2',
#       'UMLS:C1447285']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ANP32A',
#       'ANP32A gene',
#       'A0A384P5U2_HUMAN Epididymis secretory sperm binding protein (trembl)',
#       'AN32A_HUMAN Acidic leucine-rich nuclear phosphoprotein 32 family member A (sprot)',
#       'acidic leucine-rich nuclear phosphoprotein 32 family member A (human)',
#       'ANP32A protein, human']}]},
#   'NCBIGene:2314': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'FLII',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2314',
#       'ENSEMBL:ENSG00000177731',
#       'HGNC:3750',
#       'OMIM:600362',
#       'UMLS:C1414634',
#       'UniProtKB:Q13045',
#       'PR:Q13045']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['FLII',
#       'FLII gene',
#       'FLII_HUMAN Protein flightless-1 homolog (sprot)',
#       'protein flightless-1 homolog (human)']}]},
#   'NCBIGene:6230': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPS25',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6230',
#       'ENSEMBL:ENSG00000118181',
#       'HGNC:10413',
#       'OMIM:180465',
#       'UMLS:C1419727',
#       'UniProtKB:P62851',
#       'PR:P62851',
#       'ENSEMBL:ENSP00000435096',
#       'ENSEMBL:ENSP00000435096.1',
#       'ENSEMBL:ENSP00000486392',
#       'ENSEMBL:ENSP00000486392.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPS25',
#       'RPS25 gene',
#       'RS25_HUMAN 40S ribosomal protein S25 (sprot)',
#       '40S ribosomal protein S25 (human)']}]},
#   'NCBIGene:5682': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PSMA1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5682',
#       'ENSEMBL:ENSG00000129084',
#       'HGNC:9530',
#       'OMIM:602854',
#       'UMLS:C1419003',
#       'UniProtKB:B4E0X6',
#       'UniProtKB:P25786',
#       'PR:P25786']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PSMA1',
#       'PSMA1 gene',
#       'B4E0X6_HUMAN Proteasome subunit alpha type (trembl)',
#       'PSA1_HUMAN Proteasome subunit alpha type-1 (sprot)',
#       'proteasome subunit alpha type-1 (human)']}]},
#   'NCBIGene:5411': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PNN',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5411',
#       'ENSEMBL:ENSG00000100941',
#       'HGNC:9162',
#       'OMIM:603154',
#       'UMLS:C1418715',
#       'UniProtKB:Q9H307',
#       'PR:Q9H307',
#       'ENSEMBL:ENSP00000216832',
#       'ENSEMBL:ENSP00000216832.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PNN',
#       'PNN gene',
#       'PININ_HUMAN Pinin (sprot)',
#       'pinin (human)']}]},
#   'NCBIGene:801': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'CALM1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:801',
#       'ENSEMBL:ENSG00000198668',
#       'HGNC:1442',
#       'OMIM:114180',
#       'UMLS:C1332659']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['CALM1', 'CALM1 gene']}]},
#   'NCBIGene:7334': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'UBE2N',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7334',
#       'ENSEMBL:ENSG00000177889',
#       'HGNC:12492',
#       'OMIM:603679',
#       'UMLS:C1421290',
#       'UniProtKB:P61088',
#       'PR:P61088',
#       'ENSEMBL:ENSP00000316176',
#       'ENSEMBL:ENSP00000316176.2',
#       'UMLS:C1174531',
#       'UniProtKB:V9HW41']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['UBE2N',
#       'UBE2N gene',
#       'UBE2N_HUMAN Ubiquitin-conjugating enzyme E2 N (sprot)',
#       'ubiquitin-conjugating enzyme E2 N (human)',
#       'UBE2N protein, human',
#       'V9HW41_HUMAN Epididymis secretory protein Li 71 (trembl)']}]},
#   'NCBIGene:3181': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'HNRNPA2B1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3181',
#       'ENSEMBL:ENSG00000122566',
#       'HGNC:5033',
#       'OMIM:600124',
#       'UMLS:C1415636',
#       'UniProtKB:P22626',
#       'PR:P22626',
#       'UMLS:C5441626']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['HNRNPA2B1',
#       'HNRNPA2B1 gene',
#       'ROA2_HUMAN Heterogeneous nuclear ribonucleoproteins A2/B1 (sprot)',
#       'heterogeneous nuclear ribonucleoproteins A2/B1 (human)',
#       'HNRNPA2B1 protein, human']}]},
#   'NCBIGene:10921': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RNPS1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10921',
#       'ENSEMBL:ENSG00000205937',
#       'HGNC:10080',
#       'OMIM:606447',
#       'UMLS:C1419436',
#       'UniProtKB:D3DU92',
#       'UniProtKB:H3BMS0',
#       'ENSEMBL:ENSP00000454513',
#       'ENSEMBL:ENSP00000454513.1',
#       'UniProtKB:Q15287',
#       'PR:Q15287']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RNPS1',
#       'RNPS1 gene',
#       'D3DU92_HUMAN RNA-binding protein with serine-rich domain 1 (trembl)',
#       'H3BMS0_HUMAN RNA-binding protein with serine-rich domain 1 (trembl)',
#       'RNPS1_HUMAN RNA-binding protein with serine-rich domain 1 (sprot)',
#       'RNA-binding protein with serine-rich domain 1 (human)']}]},
#   'NCBIGene:832': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'CAPZB',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:832',
#       'ENSEMBL:ENSG00000077549',
#       'HGNC:1491',
#       'OMIM:601572',
#       'UMLS:C1413124',
#       'UniProtKB:A0A384MR50',
#       'UniProtKB:B1AK85',
#       'ENSEMBL:ENSP00000264203',
#       'ENSEMBL:ENSP00000264203.3',
#       'UniProtKB:B1AK88',
#       'ENSEMBL:ENSP00000401010',
#       'ENSEMBL:ENSP00000401010.1',
#       'UniProtKB:B4DWA6',
#       'UniProtKB:P47756',
#       'PR:P47756',
#       'UniProtKB:Q7L4N0']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['CAPZB',
#       'CAPZB gene',
#       'A0A384MR50_HUMAN F-actin-capping protein subunit beta (trembl)',
#       'B1AK85_HUMAN F-actin-capping protein subunit beta (trembl)',
#       'B1AK88_HUMAN F-actin-capping protein subunit beta (trembl)',
#       'B4DWA6_HUMAN F-actin-capping protein subunit beta (trembl)',
#       'CAPZB_HUMAN F-actin-capping protein subunit beta (sprot)',
#       'F-actin-capping protein subunit beta (human)',
#       'Q7L4N0_HUMAN F-actin-capping protein subunit beta (Fragment) (trembl)']}]},
#   'NCBIGene:6396': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SEC13',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6396',
#       'ENSEMBL:ENSG00000157020',
#       'HGNC:10697',
#       'OMIM:600152',
#       'UMLS:C1822665',
#       'UniProtKB:A8MWR8',
#       'UniProtKB:P55735',
#       'PR:P55735']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SEC13',
#       'SEC13 gene',
#       'A8MWR8_HUMAN Protein SEC13 homolog (trembl)',
#       'SEC13_HUMAN Protein SEC13 homolog (sprot)',
#       'protein SEC13 homolog (human)']}]},
#   'NCBIGene:27339': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PRPF19',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:27339',
#       'ENSEMBL:ENSG00000110107',
#       'HGNC:17896',
#       'OMIM:608330',
#       'UMLS:C1538720',
#       'UniProtKB:Q9UMS4',
#       'PR:Q9UMS4',
#       'ENSEMBL:ENSP00000227524',
#       'ENSEMBL:ENSP00000227524.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PRPF19',
#       'PRPF19 gene',
#       'PRP19_HUMAN Pre-mRNA-processing factor 19 (sprot)',
#       'pre-mRNA-processing factor 19 (human)']}]},
#   'NCBIGene:5718': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PSMD12',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5718',
#       'ENSEMBL:ENSG00000197170',
#       'HGNC:9557',
#       'OMIM:604450',
#       'UMLS:C1419030',
#       'UniProtKB:A0A0S2Z489',
#       'UniProtKB:O00232',
#       'PR:O00232']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PSMD12',
#       'PSMD12 gene',
#       'A0A0S2Z489_HUMAN Proteasome (Prosome, macropain) 26S subunit, non-ATPase, 12, isoform CRA_a (Fragment) (trembl)',
#       'PSD12_HUMAN 26S proteasome non-ATPase regulatory subunit 12 (sprot)',
#       '26S proteasome non-ATPase regulatory subunit 12 (human)']}]},
#   'NCBIGene:2023': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'ENO1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2023',
#       'ENSEMBL:ENSG00000074800',
#       'HGNC:3350',
#       'OMIM:172430',
#       'UMLS:C1414402',
#       'UniProtKB:A0A024R4F1',
#       'UniProtKB:P06733',
#       'PR:P06733',
#       'UMLS:C0300895']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ENO1',
#       'ENO1 gene',
#       'A0A024R4F1_HUMAN Phosphopyruvate hydratase (trembl)',
#       'ENOA_HUMAN Alpha-enolase (sprot)',
#       'alpha-enolase (human)',
#       'ENO1 protein, human']}]},
#   'NCBIGene:3508': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'IGHMBP2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3508',
#       'ENSEMBL:ENSG00000132740',
#       'HGNC:5542',
#       'OMIM:600502',
#       'UMLS:C1415994',
#       'UniProtKB:P38935',
#       'PR:P38935',
#       'ENSEMBL:ENSP00000255078',
#       'ENSEMBL:ENSP00000255078.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['IGHMBP2',
#       'IGHMBP2 gene',
#       'SMBP2_HUMAN DNA-binding protein SMUBP-2 (sprot)',
#       'DNA-binding protein SMUBP-2 (human)']}]},
#   'NCBIGene:2935': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'GSPT1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2935',
#       'ENSEMBL:ENSG00000103342',
#       'HGNC:4621',
#       'OMIM:139259',
#       'UMLS:C1415324',
#       'UniProtKB:B2RCT6',
#       'UniProtKB:P15170',
#       'PR:P15170',
#       'UniProtKB:Q7KZX8']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['GSPT1',
#       'GSPT1 gene',
#       'B2RCT6_HUMAN cDNA, FLJ96276, highly similar to Homo sapiens G1 to S phase transition 1 (GSPT1), mRNA (trembl)',
#       'ERF3A_HUMAN Eukaryotic peptide chain release factor GTP-binding subunit ERF3A (sprot)',
#       'eukaryotic peptide chain release factor GTP-binding subunit ERF3A (human)',
#       'Q7KZX8_HUMAN G1 to S phase transition 1 (trembl)']}]},
#   'NCBIGene:9584': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RBM39',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9584',
#       'ENSEMBL:ENSG00000131051',
#       'HGNC:15923',
#       'OMIM:604739',
#       'UMLS:C1826781',
#       'UniProtKB:A0A384NQ03',
#       'UniProtKB:B4DRA0',
#       'UniProtKB:E1P5S2',
#       'UniProtKB:Q14498',
#       'PR:Q14498',
#       'UniProtKB:Q6N037']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RBM39',
#       'RBM39 gene',
#       'A0A384NQ03_HUMAN Epididymis secretory sperm binding protein (trembl)',
#       'B4DRA0_HUMAN cDNA FLJ58459, highly similar to RNA-binding region-containing protein 2 (trembl)',
#       'E1P5S2_HUMAN RNA-binding region (RNP1, RRM) containing 2, isoform CRA_b (trembl)',
#       'RBM39_HUMAN RNA-binding protein 39 (sprot)',
#       'RNA-binding protein 39 (human)',
#       'Q6N037_HUMAN RNA-binding region (RNP1, RRM) containing 2, isoform CRA_d (trembl)']}]},
#   'NCBIGene:5604': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'MAP2K1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5604',
#       'ENSEMBL:ENSG00000169032',
#       'HGNC:6840',
#       'OMIM:176872',
#       'UMLS:C1334474',
#       'UniProtKB:A0A8I5KYS7',
#       'ENSEMBL:ENSP00000510309',
#       'ENSEMBL:ENSP00000510309.1',
#       'UniProtKB:A4QPA9',
#       'UniProtKB:B4DFY5',
#       'ENSEMBL:ENSP00000508437',
#       'ENSEMBL:ENSP00000508437.1',
#       'UniProtKB:H3BRW9',
#       'ENSEMBL:ENSP00000456438',
#       'ENSEMBL:ENSP00000456438.1',
#       'UniProtKB:Q02750',
#       'PR:Q02750',
#       'UMLS:C1434639']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MAP2K1',
#       'MAP2K1 gene',
#       'A0A8I5KYS7_HUMAN Dual-specificity mitogen-activated protein kinase kinase 1 (trembl)',
#       'A4QPA9_HUMAN Mitogen-activated protein kinase kinase 1 (trembl)',
#       'B4DFY5_HUMAN Dual-specificity mitogen-activated protein kinase kinase 1 (trembl)',
#       'H3BRW9_HUMAN Dual-specificity mitogen-activated protein kinase kinase 1 (trembl)',
#       'MP2K1_HUMAN Dual specificity mitogen-activated protein kinase kinase 1 (sprot)',
#       'dual specificity mitogen-activated protein kinase kinase 1 (human)',
#       'MAP2K1 protein, human']}]},
#   'NCBIGene:2771': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'GNAI2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2771',
#       'ENSEMBL:ENSG00000114353',
#       'HGNC:4385',
#       'OMIM:139360',
#       'UMLS:C1366857',
#       'UniProtKB:B3KP24',
#       'UniProtKB:B3KX51',
#       'UniProtKB:P04899',
#       'PR:P04899',
#       'UMLS:C1528046']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['GNAI2',
#       'GNAI2 gene',
#       'B3KP24_HUMAN cDNA FLJ31012 fis, clone HLUNG2000217, highly similar to Guanine nucleotide-binding protein G(i), alpha-2 subunit (trembl)',
#       'B3KX51_HUMAN cDNA FLJ44754 fis, clone BRACE3030748, highly similar to Guanine nucleotide-binding protein G(i), alpha-2 subunit (trembl)',
#       'GNAI2_HUMAN Guanine nucleotide-binding protein G(i) subunit alpha-2 (sprot)',
#       'guanine nucleotide-binding protein G(i) subunit alpha-2 (human)',
#       'GNAI2 protein, human']}]},
#   'NCBIGene:6711': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SPTBN1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6711',
#       'ENSEMBL:ENSG00000115306',
#       'HGNC:11275',
#       'OMIM:182790',
#       'UMLS:C1420388',
#       'UniProtKB:B2ZZ89',
#       'UniProtKB:Q01082',
#       'PR:Q01082',
#       'UMLS:C1121863']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SPTBN1',
#       'SPTBN1 gene',
#       'B2ZZ89_HUMAN Spectrin beta chain (trembl)',
#       'SPTB2_HUMAN Spectrin beta chain, non-erythrocytic 1 (sprot)',
#       'spectrin beta chain, non-erythrocytic 1 (human)',
#       'SPTBN1 protein, human']}]},
#   'NCBIGene:5692': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PSMB4',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5692',
#       'ENSEMBL:ENSG00000159377',
#       'HGNC:9541',
#       'OMIM:602177',
#       'UMLS:C1419014',
#       'UniProtKB:A0A140VK46',
#       'UniProtKB:P28070',
#       'PR:P28070',
#       'ENSEMBL:ENSP00000290541',
#       'ENSEMBL:ENSP00000290541.6']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PSMB4',
#       'PSMB4 gene',
#       'A0A140VK46_HUMAN Proteasome subunit beta (trembl)',
#       'PSB4_HUMAN Proteasome subunit beta type-4 (sprot)',
#       'proteasome subunit beta type-4 (human)']}]},
#   'NCBIGene:6142': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPL18A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6142',
#       'ENSEMBL:ENSG00000105640',
#       'HGNC:10311',
#       'OMIM:604178',
#       'UMLS:C1419636',
#       'UniProtKB:Q02543',
#       'PR:Q02543',
#       'ENSEMBL:ENSP00000222247',
#       'ENSEMBL:ENSP00000222247.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPL18A',
#       'RPL18A gene',
#       'RL18A_HUMAN 60S ribosomal protein L18a (sprot)',
#       '60S ribosomal protein L18a (human)']}]},
#   'NCBIGene:6144': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPL21',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6144',
#       'ENSEMBL:ENSG00000122026',
#       'HGNC:10313',
#       'OMIM:603636',
#       'UMLS:C1419637',
#       'UniProtKB:P46778',
#       'PR:P46778',
#       'ENSEMBL:ENSP00000346027',
#       'ENSEMBL:ENSP00000346027.4',
#       'ENSEMBL:ENSP00000351021',
#       'ENSEMBL:ENSP00000351021.2',
#       'ENSEMBL:ENSP00000370569',
#       'ENSEMBL:ENSP00000370569.1',
#       'ENSEMBL:ENSP00000370574',
#       'ENSEMBL:ENSP00000370574.1',
#       'UniProtKB:Q6IAX2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPL21',
#       'RPL21 gene',
#       'RL21_HUMAN 60S ribosomal protein L21 (sprot)',
#       '60S ribosomal protein L21 (human)',
#       'Q6IAX2_HUMAN 60S ribosomal protein L21 (trembl)']}]},
#   'NCBIGene:4904': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'YBX1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:4904',
#       'ENSEMBL:ENSG00000065978',
#       'HGNC:8014',
#       'OMIM:154030',
#       'UMLS:C1823882',
#       'UniProtKB:P67809',
#       'PR:P67809',
#       'ENSEMBL:ENSP00000361626',
#       'ENSEMBL:ENSP00000361626.3',
#       'UMLS:C1312886']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YBX1',
#       'YBX1 gene',
#       'YBOX1_HUMAN Y-box-binding protein 1 (sprot)',
#       'Y-box-binding protein 1 (human)',
#       'YBX1 protein, human']}]},
#   'NCBIGene:6160': {'categories': ['biolink:BiologicalEntity'],
# ...
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '750bffa2212183a002586d6650546eb6': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:2870',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '361b707fb9110c83f2f71f24bccf8b09': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:51706',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'c32bc35ab2bf49c583be59f6cc58426d': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:3162',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '30aab5b816bb5be3c4661afc16813055': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:29801',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:34079125'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '898e8ba33c0516240415d43f039f41bf': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:56951',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '157b826a7cbc72f34d8b258da443f89b': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:10159',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'b1d3023f5cc09ce24f68a789534b6c5c': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:8491',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '11d5047da658c1cfe4644d959b483a2e': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:5447',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '616d8733f092c182cda36e457d0f9e73': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:55129',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'a41432d92658241b406d68f654132878': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:80777',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '1a069755557b5f897a567375396051cf': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:4756',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '4a0a7d2af503fd9958a4d2352662f462': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:55676',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'fc54ae9d66addeea9edfd771bcf3655b': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:9537',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '06e2f19901f1399ee7156233b7272db5': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:84928',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '34f461d47d574daf0ee5ff049eacb18f': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:7355',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'b6b721aee58cabba46f9f4f6355039d7': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:51651',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'ed60247c74bb95d29a2243c7866bbd40': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:54867',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '2c217565beef0f27801199d36eeeaaa5': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:91869',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'ec16559d38398dddff52e0264b41f253': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:23786',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '2ff9429eeedf3f638fb3451aaedfbdcd': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:64121',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'ac79b9375a858ba7b1d1b53f5150434e': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:128869',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:30194290'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   ...}}

# %%
#Example: which drugs shows sensitivity with KRAS (NCBIGene:3845) altered?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids":["NCBIGene:3845"],
                    "categories":["biolink:Gene"]
                },
                "n1": {

                    "categories":["biolink:SmallMolecule"]
               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:associated_with_sensitivity_to"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL,json=query_json)
result = response.json()["message"]

# %%
print(len(result['knowledge_graph']['nodes']))
result['knowledge_graph']
# Out:
# 11
# {'nodes': {'PUBCHEM.COMPOUND:5284616': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Sirolimus',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:5284616',
#       'CHEMBL.COMPOUND:CHEMBL413',
#       'UNII:W36ZG6FT64',
#       'CHEBI:9168',
#       'DRUGBANK:DB00877',
#       'MESH:D020123',
#       'CAS:53123-88-9',
#       'DrugCentral:2446',
#       'GTOPDB:6031',
#       'KEGG.COMPOUND:C07909',
#       'INCHIKEY:QFJCIRLUMZQUOT-HPLJOQBZSA-N',
#       'UMLS:C0072980']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Sirolimus', 'SIROLIMUS', 'sirolimus']}]},
#   'NCBIGene:3845': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'KRAS',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3845',
#       'ENSEMBL:ENSG00000133703',
#       'HGNC:6407',
#       'OMIM:190070',
#       'UMLS:C1537502',
#       'UniProtKB:A0A024RAV5',
#       'UniProtKB:I1SRC5',
#       'UniProtKB:L7RSL8',
#       'UniProtKB:P01116',
#       'PR:P01116',
#       'UMLS:C0763464']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['KRAS',
#       'KRAS gene',
#       'A0A024RAV5_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog, isoform CRA_b (trembl)',
#       'I1SRC5_HUMAN UBE2L3/KRAS fusion protein (trembl)',
#       'L7RSL8_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog (trembl)',
#       'RASK_HUMAN GTPase KRas (sprot)',
#       'GTPase KRas (human)',
#       'KRAS protein, human']}]},
#   'PUBCHEM.COMPOUND:135400873': {'categories': ['biolink:MolecularEntity'],
#    'name': '(5Z)-5-(quinolin-6-ylmethylidene)-2-[(thiophen-2-ylmethyl)amino]-1,3-thiazol-4(5H)-one',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:135400873',
#       'CHEMBL.COMPOUND:CHEMBL393929',
#       'MESH:C512984',
#       'INCHIKEY:XOLMRFUGOINFDQ-YBEGLDIGSA-N',
#       'UMLS:C1743488']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['(5Z)-5-(quinolin-6-ylmethylidene)-2-[(thiophen-2-ylmethyl)amino]-1,3-thiazol-4(5H)-one',
#       'CHEMBL393929',
#       'RO 3306']}]},
#   'PUBCHEM.COMPOUND:11455910': {'categories': ['biolink:MolecularEntity'],
#    'name': 'N-[4-(2-tert-Butylphenylsulfonyl)phenyl]-2,3,4-trihydroxy-5-(2-isopropylbenzyl)benzamide',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:11455910',
#       'CHEMBL.COMPOUND:CHEMBL217354',
#       'UNII:FQ8NY4LUO5',
#       'CHEBI:95008',
#       'CAS:877877-35-5',
#       'INCHIKEY:PQAPVTKIEGUPRN-UHFFFAOYSA-N']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['N-[4-(2-tert-Butylphenylsulfonyl)phenyl]-2,3,4-trihydroxy-5-(2-isopropylbenzyl)benzamide',
#       'CHEMBL217354',
#       'TW-37',
#       'N-[4-(2-tert-butylphenyl)sulfonylphenyl]-2,3,4-trihydroxy-5-[(2-propan-2-ylphenyl)methyl]benzamide']}]},
#   'PUBCHEM.COMPOUND:46844147': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Erk5-IN-1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:46844147',
#       'CHEMBL.COMPOUND:CHEMBL1673039',
#       'CHEBI:91375',
#       'CAS:1234479-76-5',
#       'INCHIKEY:DDTPGANIPBKTNU-UHFFFAOYSA-N']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Erk5-IN-1',
#       'CHEMBL1673039',
#       '2-[2-methoxy-4-(4-methyl-1-piperazinyl)anilino]-5,11-dimethyl-6-pyrimido[4,5-b][1,4]benzodiazepinone']}]},
#   'PUBCHEM.COMPOUND:46843772': {'categories': ['biolink:MolecularEntity'],
#    'name': '2-{[2-ethoxy-4-(4-hydroxypiperidin-1-yl)phenyl]amino}-5,11-dimethyl-5,11-dihydro-6H-pyrimido[4,5-b][1,4]benzodiazepin-6-one',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:46843772',
#       'CHEMBL.COMPOUND:CHEMBL1673046',
#       'CHEBI:60325',
#       'MESH:C568790',
#       'CAS:1234480-50-2',
#       'GTOPDB:8057',
#       'INCHIKEY:QAPAJIZPZGWAND-UHFFFAOYSA-N',
#       'UMLS:C3252765']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['2-{[2-ethoxy-4-(4-hydroxypiperidin-1-yl)phenyl]amino}-5,11-dimethyl-5,11-dihydro-6H-pyrimido[4,5-b][1,4]benzodiazepin-6-one',
#       'CHEMBL1673046',
#       'XMD8-92',
#       'XMD 8-92']}]},
#   'PUBCHEM.COMPOUND:25227436': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Capivasertib',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:25227436',
#       'CHEMBL.COMPOUND:CHEMBL2325741',
#       'UNII:WFR23M21IE',
#       'DRUGBANK:DB12218',
#       'MESH:C575618',
#       'CAS:1143532-39-1',
#       'GTOPDB:7709',
#       'INCHIKEY:JDUBGYFRJFOXQC-KRWDZBQOSA-N',
#       'UMLS:C4682387']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Capivasertib', 'CAPIVASERTIB', 'capivasertib']}]},
#   'PUBCHEM.COMPOUND:71748056': {'categories': ['biolink:MolecularEntity'],
#    'name': '9-(1-Methyl-4-pyrazolyl)-1-[1-(1-oxoprop-2-enyl)-2,3-dihydroindol-6-yl]-2-benzo[h][1,6]naphthyridinone',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:71748056',
#       'CHEMBL.COMPOUND:CHEMBL4077064',
#       'CHEBI:94815',
#       'CAS:1469988-75-7',
#       'INCHIKEY:RTRNJQOBEOISFQ-UHFFFAOYSA-N']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['9-(1-Methyl-4-pyrazolyl)-1-[1-(1-oxoprop-2-enyl)-2,3-dihydroindol-6-yl]-2-benzo[h][1,6]naphthyridinone',
#       'CHEMBL4077064',
#       '9-(1-methyl-4-pyrazolyl)-1-[1-(1-oxoprop-2-enyl)-2,3-dihydroindol-6-yl]-2-benzo[h][1,6]naphthyridinone']}]},
#   'PUBCHEM.COMPOUND:25226117': {'categories': ['biolink:MolecularEntity'],
#    'name': '1-[4-[[4-Amino-5-chloro-6-(2-propan-2-ylsulfonylanilino)-2-pyrimidinyl]amino]-3-methoxyphenyl]-4-piperidinecarboxamide',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:25226117',
#       'CHEMBL.COMPOUND:CHEMBL3392893',
#       'CHEBI:94486',
#       'CAS:1125593-85-2',
#       'INCHIKEY:IMEGLYUXMGWVQA-UHFFFAOYSA-N']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['1-[4-[[4-Amino-5-chloro-6-(2-propan-2-ylsulfonylanilino)-2-pyrimidinyl]amino]-3-methoxyphenyl]-4-piperidinecarboxamide',
#       'CHEMBL3392893',
#       '1-[4-[[4-amino-5-chloro-6-(2-propan-2-ylsulfonylanilino)-2-pyrimidinyl]amino]-3-methoxyphenyl]-4-piperidinecarboxamide']}]},
#   'PUBCHEM.COMPOUND:3062316': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Dasatinib',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:3062316',
#       'CHEMBL.COMPOUND:CHEMBL1421',
#       'UNII:X78UG0A0RN',
#       'CHEBI:49375',
#       'DRUGBANK:DB01254',
#       'CAS:302962-49-8',
#       'DrugCentral:785',
#       'GTOPDB:5678',
#       'HMDB:HMDB0015384',
#       'INCHIKEY:ZBNZXTGUTAYRHI-UHFFFAOYSA-N',
#       'UMLS:C1455147',
#       'UMLS:C2699562']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Dasatinib',
#       'DASATINIB',
#       'DASATINIB ANHYDROUS',
#       'dasatinib (anhydrous)',
#       'dasatinib',
#       'dasatinib anhydrous']}]},
#   'PUBCHEM.COMPOUND:11707110': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Trametinib',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:11707110',
#       'CHEMBL.COMPOUND:CHEMBL2103875',
#       'UNII:33E86K87QN',
#       'CHEBI:75998',
#       'DRUGBANK:DB08911',
#       'MESH:C560077',
#       'CAS:871700-17-3',
#       'DrugCentral:4802',
#       'GTOPDB:6495',
#       'INCHIKEY:LIRYPHYGHXZJBZ-UHFFFAOYSA-N',
#       'UMLS:C2697961']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Trametinib', 'TRAMETINIB', 'trametinib']}]}},
#  'edges': {'082973798d8d5c4caa080a198d17ca2d': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:5284616',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 'Spearman Correlation Test was used to extract the association',
#        'value': 'NCIT:C53249',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0045477337439671,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 13},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Gene expression'},
#     {'attribute_type_id': 'biolink:object_aspect_qualifier', 'value': 'AUC'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0006143'}]},
#   '5d2298ba310092105bec6000d5078bf8': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:135400873',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 'Spearman Correlation Test was used to extract the association',
#        'value': 'NCIT:C53249',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0097595359599169,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 11},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Gene expression'},
#     {'attribute_type_id': 'biolink:object_aspect_qualifier', 'value': 'AUC'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0005005'}]},
#   'dcc2c34437e0a335aabd17c6ce2d14ed': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:11455910',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 'Spearman Correlation Test was used to extract the association',
#        'value': 'NCIT:C53249',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0052129065583094,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 29},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Gene expression'},
#     {'attribute_type_id': 'biolink:object_aspect_qualifier', 'value': 'AUC'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0005005'}]},
#   'b00ab371759819f7918bc0edf0c45737': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:46844147',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 'Spearman Correlation Test was used to extract the association',
#        'value': 'NCIT:C53249',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.002445197640446,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 14},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Gene expression'},
#     {'attribute_type_id': 'biolink:object_aspect_qualifier', 'value': 'AUC'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0007256'}]},
#   '0faa7f412bd3098ca1dff0013654647a': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:46843772',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 'Spearman Correlation Test was used to extract the association',
#        'value': 'NCIT:C53249',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0046770192376274,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 23},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Gene expression'},
#     {'attribute_type_id': 'biolink:object_aspect_qualifier', 'value': 'AUC'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0005005'}]},
#   'dbe567591c14ef6e0832ff6fce63d854': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:25227436',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 't-test was used to compute the p-value for the association',
#        'value': 'NCIT:C53231',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0030981662650149,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 31},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Genetic variants'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0006046'}]},
#   '7f77d904f34f5d27e49219e73f198c93': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:71748056',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 't-test was used to compute the p-value for the association',
#        'value': 'NCIT:C53231',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0129453501806996,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 31},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Genetic variants'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0006046'}]},
#   'fddca6e47a4a0a4f57bba10cc25f046c': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:25226117',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 't-test was used to compute the p-value for the association',
#        'value': 'NCIT:C53231',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0244706215734285,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 31},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Genetic variants'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0006046'}]},
#   'eea7c2d26d5c7ca13128c3cc1053b6a6': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:3062316',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 't-test was used to compute the p-value for the association',
#        'value': 'NCIT:C53231',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.003351248050487,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 31},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Genetic variants'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0006046'}]},
#   'a0b95d148e43cc3cf205e20df6ccb150': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:11707110',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 't-test was used to compute the p-value for the association',
#        'value': 'NCIT:C53231',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0001374022258134,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 59},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Genetic variants'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0005061'}]}}}

# %%
# Example: what drugs or small molecules that target BCL2 (NCBIGene: 596)?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "categories":["biolink:SmallMolecule"]
                },
                "n1": {
                    "ids":["NCBIGene:596"],
                    "categories":["biolink:Gene"]
                    
               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:physically_interacts_with"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL,json=query_json)
result = response.json()["message"]

# %%
print(len(result['knowledge_graph']['nodes']))
result['knowledge_graph']
# Out:
# 7
# {'nodes': {'NCBIGene:596': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'BCL2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:596',
#       'ENSEMBL:ENSG00000171791',
#       'HGNC:990',
#       'OMIM:151430',
#       'UMLS:C0376515',
#       'UniProtKB:A0A024R2B3',
#       'UniProtKB:A0A024R2C4',
#       'UniProtKB:A0A7I2V3S7',
#       'ENSEMBL:ENSP00000503628',
#       'ENSEMBL:ENSP00000503628.1',
#       'UniProtKB:P10415',
#       'PR:P10415',
#       'UMLS:C4042483']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['BCL2',
#       'BCL2 gene',
#       'A0A024R2B3_HUMAN Apoptosis regulator Bcl-2 (trembl)',
#       'A0A024R2C4_HUMAN Apoptosis regulator Bcl-2 (trembl)',
#       'A0A7I2V3S7_HUMAN Apoptosis regulator Bcl-2 (trembl)',
#       'BCL2_HUMAN Apoptosis regulator Bcl-2 (sprot)',
#       'apoptosis regulator Bcl-2 (human)',
#       'BCL2 protein, human']}]},
#   'PUBCHEM.COMPOUND:2710': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Chlorcyclizine',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:2710',
#       'CHEMBL.COMPOUND:CHEMBL22150',
#       'UNII:M26C4IP44P',
#       'CHEBI:94402',
#       'DRUGBANK:DB08936',
#       'MESH:C084597',
#       'CAS:82-93-9',
#       'DrugCentral:593',
#       'HMDB:HMDB0240224',
#       'INCHIKEY:WFNAKBGANONZEQ-UHFFFAOYSA-N',
#       'UMLS:C0008183']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Chlorcyclizine',
#       'CHLORCYCLIZINE',
#       '1-[(4-chlorophenyl)-phenylmethyl]-4-methylpiperazine',
#       'chlorcyclizine']}]},
#   'PUBCHEM.COMPOUND:3503': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Gossypol',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:3503',
#       'CHEMBL.COMPOUND:CHEMBL51483',
#       'UNII:8DY2X8LXW4',
#       'UNII:KAV15B369O',
#       'UNII:XNA7DR63CQ',
#       'DRUGBANK:DB13044',
#       'MESH:D006072',
#       'CAS:20300-26-9',
#       'DrugCentral:1328',
#       'GTOPDB:4204',
#       'HMDB:HMDB0040723',
#       'KEGG.COMPOUND:C07667',
#       'INCHIKEY:QBKSWRVVCFFDOT-UHFFFAOYSA-N',
#       'UMLS:C0018096']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Gossypol',
#       'GOSSYPOL',
#       'GOSSYPOL, (R)-',
#       'GOSSYPOL, (S)-',
#       'gossypol',
#       '(-)-Gossypol']}]},
#   'PUBCHEM.COMPOUND:11404337': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Obatoclax',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:11404337',
#       'INCHIKEY:CVCLJVVBHYOXDC-IAZSKANUSA-N']},
#     {'attribute_type_id': 'biolink:synonym', 'value': ['Obatoclax']}]},
#   'PUBCHEM.COMPOUND:11228183': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Abt-737',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:11228183',
#       'CHEMBL.COMPOUND:CHEMBL376408',
#       'UNII:Z5NFR173NV',
#       'CHEBI:47575',
#       'MESH:C501332',
#       'CAS:852808-04-9',
#       'GTOPDB:8320',
#       'INCHIKEY:HPLNQCPCUACXLM-PGUFJCEWSA-N',
#       'UMLS:C1570187']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Abt-737', 'ABT 737', 'ABT-737']}]},
#   'PUBCHEM.COMPOUND:454878': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Apogossypol',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:454878',
#       'CHEMBL.COMPOUND:CHEMBL551288',
#       'MESH:C492806',
#       'INCHIKEY:PBJKWGWHZVXBGU-UHFFFAOYSA-N',
#       'UMLS:C1528430']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Apogossypol', 'APOGOSSYPOL', 'apogossypol']}]},
#   'PUBCHEM.COMPOUND:49846579': {'categories': ['biolink:MolecularEntity'],
#    'name': 'Venetoclax',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:49846579',
#       'CHEMBL.COMPOUND:CHEMBL3137309',
#       'UNII:N54AIC43PW',
#       'CHEBI:133021',
#       'DRUGBANK:DB11581',
#       'MESH:C579720',
#       'CAS:1257044-40-8',
#       'DrugCentral:5133',
#       'GTOPDB:8318',
#       'INCHIKEY:LQBVNQSMGBZMKD-UHFFFAOYSA-N',
#       'UMLS:C4079830']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Venetoclax', 'VENETOCLAX', 'venetoclax']}]}},
#  'edges': {'decc6f2a06cde6693bf53a8797855ead': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:2710',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:drugcentral'}],
#      'value': 'infores:drugcentral'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'd06de37ea2107e5390950a12ced2eac3': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:3503',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:ttd'}],
#      'value': 'infores:ttd'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '81caf80b13672b2a53386557ce4304fb': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:11404337',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:ttd'}],
#      'value': 'infores:ttd'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'b159a5aebecf8422f4436aa9d3602b72': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:11228183',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:ttd'}],
#      'value': 'infores:ttd'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   '0e1167b374501d027ceb90c6bb57b25d': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:454878',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:ttd'}],
#      'value': 'infores:ttd'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]},
#   'c326da9c79d204d816053f95b1d470a2': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:49846579',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:drugcentral'}],
#      'value': 'infores:drugcentral'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}]}}}

# %%
# Example: what are the potential biomarkser for liver cancer (MONDO:0007256)?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids":["MONDO:0007256"],
                    "categories":["biolink:Disease"]
                },
                "n1": {
                    "categories":["biolink:Gene"]
                    
               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:has_biomarker"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL,json=query_json)
result = response.json()["message"]

# %%
# Example: what are the genes that are negatively correlcted with KRAS (NCBIGene:3845) ?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids":["NCBIGene:3845"],
                    "categories":["biolink:Gene"]
                },
                "n1": {
                    "categories":["biolink:Gene"]
                    
               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:positively_correlated_with"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL,json=query_json)
result = response.json()["message"]

# %%
result['knowledge_graph']
# Out:
# {'nodes': {'NCBIGene:83732': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RIOK1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:83732',
#       'ENSEMBL:ENSG00000124784',
#       'HGNC:18656',
#       'OMIM:617753',
#       'UMLS:C1425683',
#       'UniProtKB:Q9BRS2',
#       'PR:Q9BRS2',
#       'ENSEMBL:ENSP00000369162',
#       'ENSEMBL:ENSP00000369162.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RIOK1',
#       'RIOK1 gene',
#       'RIOK1_HUMAN Serine/threonine-protein kinase RIO1 (sprot)',
#       'serine/threonine-protein kinase RIO1 (human)']}]},
#   'NCBIGene:3845': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'KRAS',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3845',
#       'ENSEMBL:ENSG00000133703',
#       'HGNC:6407',
#       'OMIM:190070',
#       'UMLS:C1537502',
#       'UniProtKB:A0A024RAV5',
#       'UniProtKB:I1SRC5',
#       'UniProtKB:L7RSL8',
#       'UniProtKB:P01116',
#       'PR:P01116',
#       'UMLS:C0763464']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['KRAS',
#       'KRAS gene',
#       'A0A024RAV5_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog, isoform CRA_b (trembl)',
#       'I1SRC5_HUMAN UBE2L3/KRAS fusion protein (trembl)',
#       'L7RSL8_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog (trembl)',
#       'RASK_HUMAN GTPase KRas (sprot)',
#       'GTPase KRas (human)',
#       'KRAS protein, human']}]},
#   'NCBIGene:54887': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'BLTP3A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:54887',
#       'ENSEMBL:ENSG00000065060',
#       'HGNC:21216',
#       'OMIM:619570',
#       'UMLS:C1427423',
#       'UniProtKB:Q6BDS2',
#       'PR:Q6BDS2',
#       'ENSEMBL:ENSP00000192788',
#       'ENSEMBL:ENSP00000192788.5']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['BLTP3A',
#       'UHRF1BP1 gene',
#       'URFB1_HUMAN UHRF1-binding protein 1 (sprot)',
#       'UHRF1-binding protein 1 (human)']}]},
#   'NCBIGene:10492': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SYNCRIP',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10492',
#       'ENSEMBL:ENSG00000135316',
#       'HGNC:16918',
#       'OMIM:616686',
#       'UMLS:C1424633',
#       'UniProtKB:A0A7I2V309',
#       'ENSEMBL:ENSP00000503183',
#       'ENSEMBL:ENSP00000503183.1',
#       'UniProtKB:A0A7I2YQN2',
#       'ENSEMBL:ENSP00000504086',
#       'ENSEMBL:ENSP00000504086.1',
#       'ENSEMBL:ENSP00000504816',
#       'ENSEMBL:ENSP00000504816.1',
#       'UniProtKB:B7Z645',
#       'ENSEMBL:ENSP00000484577',
#       'ENSEMBL:ENSP00000484577.1',
#       'ENSEMBL:ENSP00000506874',
#       'ENSEMBL:ENSP00000506874.1',
#       'ENSEMBL:ENSP00000507008',
#       'ENSEMBL:ENSP00000507008.1',
#       'ENSEMBL:ENSP00000507581',
#       'ENSEMBL:ENSP00000507581.1',
#       'ENSEMBL:ENSP00000507623',
#       'ENSEMBL:ENSP00000507623.1',
#       'UniProtKB:O60506',
#       'PR:O60506',
#       'UniProtKB:Q59GL1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SYNCRIP',
#       'SYNCRIP gene',
#       'A0A7I2V309_HUMAN Heterogeneous nuclear ribonucleoprotein Q (trembl)',
#       'A0A7I2YQN2_HUMAN Heterogeneous nuclear ribonucleoprotein Q (trembl)',
#       'B7Z645_HUMAN Heterogeneous nuclear ribonucleoprotein Q (trembl)',
#       'HNRPQ_HUMAN Heterogeneous nuclear ribonucleoprotein Q (sprot)',
#       'heterogeneous nuclear ribonucleoprotein Q (human)',
#       'Q59GL1_HUMAN Synaptotagmin binding, cytoplasmic RNA interacting protein variant (Fragment) (trembl)']}]},
#   'NCBIGene:84154': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RPF2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:84154',
#       'ENSEMBL:ENSG00000197498',
#       'HGNC:20870',
#       'OMIM:618471',
#       'UMLS:C1427176',
#       'UniProtKB:Q9H7B2',
#       'PR:Q9H7B2',
#       'ENSEMBL:ENSP00000402338',
#       'ENSEMBL:ENSP00000402338.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPF2',
#       'RPF2 gene',
#       'RPF2_HUMAN Ribosome production factor 2 homolog (sprot)',
#       'ribosome production factor 2 homolog (human)']}]},
#   'NCBIGene:8797': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'TNFRSF10A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8797',
#       'ENSEMBL:ENSG00000104689',
#       'HGNC:11904',
#       'OMIM:603611',
#       'UMLS:C1336643',
#       'UniProtKB:O00220',
#       'PR:O00220',
#       'ENSEMBL:ENSP00000221132',
#       'ENSEMBL:ENSP00000221132.3',
#       'UMLS:C1504635']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TNFRSF10A',
#       'TNFRSF10A gene',
#       'TR10A_HUMAN Tumor necrosis factor receptor superfamily member 10A (sprot)',
#       'tumor necrosis factor receptor superfamily member 10A (human)',
#       'TNFRSF10A protein, human']}]},
#   'NCBIGene:5516': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PPP2CB',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5516',
#       'ENSEMBL:ENSG00000104695',
#       'HGNC:9300',
#       'OMIM:176916',
#       'UMLS:C1335242',
#       'UniProtKB:A0A140VJS0',
#       'UniProtKB:P62714',
#       'PR:P62714',
#       'ENSEMBL:ENSP00000221138',
#       'ENSEMBL:ENSP00000221138.4',
#       'UMLS:C1335540']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PPP2CB',
#       'PPP2CB gene',
#       'A0A140VJS0_HUMAN Serine/threonine-protein phosphatase (trembl)',
#       'PP2AB_HUMAN Serine/threonine-protein phosphatase 2A catalytic subunit beta isoform (sprot)',
#       'serine/threonine-protein phosphatase 2A catalytic subunit beta isoform (human)',
#       'PPP2CB protein, human']}]},
#   'NCBIGene:81034': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SLC25A32',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:81034',
#       'ENSEMBL:ENSG00000164933',
#       'HGNC:29683',
#       'OMIM:138480',
#       'UMLS:C1822742',
#       'UniProtKB:Q9H2D1',
#       'PR:Q9H2D1',
#       'ENSEMBL:ENSP00000297578',
#       'ENSEMBL:ENSP00000297578.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC25A32',
#       'SLC25A32 gene',
#       'MFTC_HUMAN Mitochondrial folate transporter/carrier (sprot)',
#       'mitochondrial folate transporter/carrier (human)']}]},
#   'NCBIGene:10730': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'YME1L1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10730',
#       'ENSEMBL:ENSG00000136758',
#       'HGNC:12843',
#       'OMIM:607472',
#       'UMLS:C1421554',
#       'UniProtKB:Q96TA2',
#       'PR:Q96TA2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YME1L1',
#       'YME1L1 gene',
#       'YMEL1_HUMAN ATP-dependent zinc metalloprotease YME1L1 (sprot)',
#       'ATP-dependent zinc metalloprotease YME1L1 (human)']}]},
#   'NCBIGene:10285': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SMNDC1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10285',
#       'ENSEMBL:ENSG00000119953',
#       'HGNC:16900',
#       'OMIM:603519',
#       'UMLS:C1424623',
#       'UniProtKB:O75940',
#       'PR:O75940',
#       'ENSEMBL:ENSP00000358605',
#       'ENSEMBL:ENSP00000358605.1',
#       'ENSEMBL:ENSP00000358616',
#       'ENSEMBL:ENSP00000358616.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SMNDC1',
#       'SMNDC1 gene',
#       'SPF30_HUMAN Survival of motor neuron-related-splicing factor 30 (sprot)',
#       'survival of motor neuron-related-splicing factor 30 (human)']}]},
#   'NCBIGene:10179': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RBM7',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10179',
#       'ENSEMBL:ENSG00000076053',
#       'HGNC:9904',
#       'OMIM:612413',
#       'UMLS:C1419302',
#       'UniProtKB:G3V1T9',
#       'ENSEMBL:ENSP00000445848',
#       'ENSEMBL:ENSP00000445848.1',
#       'UniProtKB:J3KPD3',
#       'ENSEMBL:ENSP00000364639',
#       'ENSEMBL:ENSP00000364639.5',
#       'UniProtKB:Q9Y580',
#       'PR:Q9Y580',
#       'ENSEMBL:ENSP00000439918',
#       'ENSEMBL:ENSP00000439918.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RBM7',
#       'RBM7 gene',
#       'G3V1T9_HUMAN RNA binding motif protein 7, isoform CRA_a (trembl)',
#       'J3KPD3_HUMAN RNA binding motif protein 7, isoform CRA_c (trembl)',
#       'RBM7_HUMAN RNA-binding protein 7 (sprot)',
#       'RNA-binding protein 7 (human)']}]},
#   'NCBIGene:5756': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'TWF1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5756',
#       'ENSEMBL:ENSG00000151239',
#       'HGNC:9620',
#       'OMIM:610932',
#       'UMLS:C1823556',
#       'UniProtKB:Q12792',
#       'PR:Q12792']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TWF1',
#       'TWF1 gene',
#       'TWF1_HUMAN Twinfilin-1 (sprot)',
#       'twinfilin-1 (human)']}]},
#   'NCBIGene:10054': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'UBA2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10054',
#       'ENSEMBL:ENSG00000126261',
#       'HGNC:30661',
#       'OMIM:613295',
#       'UMLS:C1826967',
#       'UniProtKB:Q9UBT2',
#       'PR:Q9UBT2',
#       'UMLS:C1306952']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['UBA2',
#       'UBA2 gene',
#       'SAE2_HUMAN SUMO-activating enzyme subunit 2 (sprot)',
#       'SUMO-activating enzyme subunit 2 (human)',
#       'UBA2 protein, human']}]},
#   'NCBIGene:5621': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PRNP',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5621',
#       'ENSEMBL:ENSG00000171867',
#       'HGNC:9449',
#       'OMIM:176640',
#       'UMLS:C1418941',
#       'UniProtKB:F7VJQ1',
#       'UniProtKB:P04156',
#       'PR:P04156',
#       'UMLS:C2346932',
#       'UniProtKB:Q53YK7']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PRNP',
#       'PRNP gene',
#       'APRIO_HUMAN Alternative prion protein (sprot)',
#       'PRIO_HUMAN Major prion protein (sprot)',
#       'major prion protein (human)',
#       'Major Prion Protein, Human',
#       'Q53YK7_HUMAN Major prion protein (trembl)']}]},
#   'NCBIGene:57403': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RAB22A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57403',
#       'ENSEMBL:ENSG00000124209',
#       'HGNC:9764',
#       'OMIM:612966',
#       'UMLS:C1419193',
#       'UniProtKB:Q9UL26',
#       'PR:Q9UL26',
#       'ENSEMBL:ENSP00000244040',
#       'ENSEMBL:ENSP00000244040.3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAB22A',
#       'RAB22A gene',
#       'RB22A_HUMAN Ras-related protein Rab-22A (sprot)',
#       'Ras-related protein Rab-22A (human)']}]},
#   'NCBIGene:51012': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PRELID3B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:51012',
#       'ENSEMBL:ENSG00000101166',
#       'HGNC:15892',
#       'UMLS:C1423812',
#       'UniProtKB:Q9Y3B1',
#       'PR:Q9Y3B1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PRELID3B',
#       'PRELID3B gene',
#       'PLD3B_HUMAN PRELI domain containing protein 3B (sprot)',
#       'PRELI domain containing protein 3B (human)']}]},
#   'NCBIGene:23760': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PITPNB',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23760',
#       'ENSEMBL:ENSG00000180957',
#       'HGNC:9002',
#       'OMIM:606876',
#       'UMLS:C1418593',
#       'UniProtKB:P48739',
#       'PR:P48739']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PITPNB',
#       'PITPNB gene',
#       'PIPNB_HUMAN Phosphatidylinositol transfer protein beta isoform (sprot)',
#       'phosphatidylinositol transfer protein beta isoform (human)']}]},
#   'NCBIGene:79691': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'QTRT2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:79691',
#       'ENSEMBL:ENSG00000151576',
#       'HGNC:25771',
#       'UMLS:C1428518',
#       'UniProtKB:Q9H974',
#       'PR:Q9H974']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['QTRT2',
#       'QTRT2 gene',
#       'QTRT2_HUMAN Queuine tRNA-ribosyltransferase accessory subunit 2 (sprot)',
#       'queuine tRNA-ribosyltransferase accessory subunit 2 (human)']}]},
#   'NCBIGene:166929': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SGMS2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:166929',
#       'ENSEMBL:ENSG00000164023',
#       'HGNC:28395',
#       'OMIM:611574',
#       'UMLS:C1969043',
#       'UniProtKB:A0A024RDH4',
#       'UniProtKB:Q8NHU3',
#       'PR:Q8NHU3',
#       'ENSEMBL:ENSP00000351981',
#       'ENSEMBL:ENSP00000351981.4',
#       'ENSEMBL:ENSP00000378176',
#       'ENSEMBL:ENSP00000378176.4',
#       'ENSEMBL:ENSP00000378178',
#       'ENSEMBL:ENSP00000378178.3',
#       'ENSEMBL:ENSP00000508566',
#       'ENSEMBL:ENSP00000508566.1',
#       'UMLS:C3641910']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SGMS2',
#       'SGMS2 gene',
#       'A0A024RDH4_HUMAN PAP2_C domain-containing protein (trembl)',
#       'SMS2_HUMAN Phosphatidylcholine:ceramide cholinephosphotransferase 2 (sprot)',
#       'phosphatidylcholine:ceramide cholinephosphotransferase 2 (human)',
#       'Phosphatidylcholine:Ceramide Cholinephosphotransferase 2']}]},
#   'NCBIGene:54545': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'MTMR12',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:54545',
#       'ENSEMBL:ENSG00000150712',
#       'HGNC:18191',
#       'OMIM:606501',
#       'UMLS:C1538024',
#       'UniProtKB:Q9C0I1',
#       'PR:Q9C0I1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MTMR12',
#       'MTMR12 gene',
#       'MTMRC_HUMAN Myotubularin-related protein 12 (sprot)',
#       'myotubularin-related protein 12 (human)']}]},
#   'NCBIGene:88745': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RRP36',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:88745',
#       'ENSEMBL:ENSG00000124541',
#       'HGNC:21374',
#       'OMIM:613475',
#       'UMLS:C1427520',
#       'UniProtKB:Q96EU6',
#       'PR:Q96EU6']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RRP36',
#       'RRP36 gene',
#       'RRP36_HUMAN Ribosomal RNA processing protein 36 homolog (sprot)',
#       'ribosomal RNA processing protein 36 homolog (human)']}]},
#   'NCBIGene:50640': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PNPLA8',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:50640',
#       'ENSEMBL:ENSG00000135241',
#       'HGNC:28900',
#       'OMIM:612123',
#       'UMLS:C1826639',
#       'UniProtKB:A0A024R746',
#       'UniProtKB:Q9NP80',
#       'PR:Q9NP80']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PNPLA8',
#       'PNPLA8 gene',
#       'A0A024R746_HUMAN Intracellular membrane-associated calcium-independent phospholipase A2 gamma, isoform CRA_a (trembl)',
#       'PLPL8_HUMAN Calcium-independent phospholipase A2-gamma (sprot)',
#       'calcium-independent phospholipase A2-gamma (human)']}]},
#   'NCBIGene:5049': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PAFAH1B2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5049',
#       'ENSEMBL:ENSG00000168092',
#       'HGNC:8575',
#       'OMIM:602508',
#       'UMLS:C1418246',
#       'UniProtKB:P68402',
#       'PR:P68402',
#       'UMLS:C3273681',
#       'UniProtKB:V9HW44']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PAFAH1B2',
#       'PAFAH1B2 gene',
#       'PA1B2_HUMAN Platelet-activating factor acetylhydrolase IB subunit alpha2 (sprot)',
#       'platelet-activating factor acetylhydrolase IB subunit alpha2 (human)',
#       'Platelet-Activating Factor Acetylhydrolase IB Subunit Beta',
#       'V9HW44_HUMAN Epididymis secretory protein Li 303 (trembl)']}]},
#   'NCBIGene:23011': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RAB21',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23011',
#       'ENSEMBL:ENSG00000080371',
#       'HGNC:18263',
#       'OMIM:612398',
#       'UMLS:C1425403',
#       'UniProtKB:A0A024RBA9',
#       'UniProtKB:Q9UL25',
#       'PR:Q9UL25',
#       'ENSEMBL:ENSP00000261263',
#       'ENSEMBL:ENSP00000261263.3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAB21',
#       'RAB21 gene',
#       'A0A024RBA9_HUMAN Ras-related protein Rab-21 (trembl)',
#       'RAB21_HUMAN Ras-related protein Rab-21 (sprot)',
#       'Ras-related protein Rab-21 (human)']}]},
#   'NCBIGene:197131': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'UBR1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:197131',
#       'ENSEMBL:ENSG00000159459',
#       'HGNC:16808',
#       'OMIM:605981',
#       'UMLS:C1424562',
#       'UniProtKB:Q8IWV7',
#       'PR:Q8IWV7']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['UBR1',
#       'UBR1 gene',
#       'UBR1_HUMAN E3 ubiquitin-protein ligase UBR1 (sprot)',
#       'E3 ubiquitin-protein ligase UBR1 (human)']}]},
#   'NCBIGene:7874': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'USP7',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7874',
#       'ENSEMBL:ENSG00000187555',
#       'HGNC:12630',
#       'OMIM:602519',
#       'UMLS:C1421408',
#       'UniProtKB:B7Z855',
#       'UniProtKB:B7ZAX6',
#       'UniProtKB:Q6U8A4',
#       'UniProtKB:Q93009',
#       'PR:Q93009',
#       'UMLS:C1142946']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['USP7',
#       'USP7 gene',
#       'B7Z855_HUMAN Ubiquitin carboxyl-terminal hydrolase 7 (trembl)',
#       'B7ZAX6_HUMAN Ubiquitin carboxyl-terminal hydrolase 7 (trembl)',
#       'Q6U8A4_HUMAN Ubiquitin carboxyl-terminal hydrolase 7 (Fragment) (trembl)',
#       'UBP7_HUMAN Ubiquitin carboxyl-terminal hydrolase 7 (sprot)',
#       'ubiquitin carboxyl-terminal hydrolase 7 (human)',
#       'USP7 protein, human']}]},
#   'NCBIGene:7150': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'TOP1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7150',
#       'ENSEMBL:ENSG00000198900',
#       'HGNC:11986',
#       'OMIM:126420',
#       'UMLS:C1336656',
#       'UniProtKB:P11387',
#       'PR:P11387',
#       'ENSEMBL:ENSP00000354522',
#       'ENSEMBL:ENSP00000354522.2',
#       'UMLS:C1458146',
#       'UniProtKB:Q9BVT2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TOP1',
#       'TOP1 gene',
#       'TOP1_HUMAN DNA topoisomerase 1 (sprot)',
#       'DNA topoisomerase 1 (human)',
#       'TOP1 protein, human',
#       'Q9BVT2_HUMAN TOPEUc domain-containing protein (Fragment) (trembl)']}]},
#   'NCBIGene:8073': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PTP4A2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8073',
#       'ENSEMBL:ENSG00000184007',
#       'HGNC:9635',
#       'OMIM:601584',
#       'UMLS:C1419089',
#       'UniProtKB:Q12974',
#       'PR:Q12974']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PTP4A2',
#       'PTP4A2 gene',
#       'TP4A2_HUMAN Protein tyrosine phosphatase type IVA 2 (sprot)',
#       'protein tyrosine phosphatase type IVA 2 (human)']}]},
#   'NCBIGene:57708': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'MIER1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57708',
#       'ENSEMBL:ENSG00000198160',
#       'HGNC:29657',
#       'OMIM:616848',
#       'UMLS:C1825991',
#       'UniProtKB:Q8N108',
#       'PR:Q8N108']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MIER1',
#       'MIER1 gene',
#       'MIER1_HUMAN Mesoderm induction early response protein 1 (sprot)',
#       'mesoderm induction early response protein 1 (human)']}]},
#   'NCBIGene:64645': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'MFSD14A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:64645',
#       'ENSEMBL:ENSG00000156875',
#       'HGNC:23363',
#       'UMLS:C1428051',
#       'UniProtKB:Q96MC6',
#       'PR:Q96MC6',
#       'ENSEMBL:ENSP00000359171',
#       'ENSEMBL:ENSP00000359171.3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MFSD14A',
#       'MFSD14A gene',
#       'MF14A_HUMAN Hippocampus abundant transcript 1 protein (sprot)',
#       'hippocampus abundant transcript 1 protein (human)']}]},
#   'NCBIGene:56902': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PNO1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:56902',
#       'ENSEMBL:ENSG00000115946',
#       'HGNC:32790',
#       'OMIM:618710',
#       'UMLS:C1826636',
#       'UniProtKB:Q9NRX1',
#       'PR:Q9NRX1',
#       'ENSEMBL:ENSP00000263657',
#       'ENSEMBL:ENSP00000263657.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PNO1',
#       'PNO1 gene',
#       'PNO1_HUMAN RNA-binding protein PNO1 (sprot)',
#       'RNA-binding protein PNO1 (human)']}]},
#   'NCBIGene:3987': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'LIMS1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3987',
#       'ENSEMBL:ENSG00000169756',
#       'HGNC:6616',
#       'OMIM:602567',
#       'UMLS:C1366510',
#       'UniProtKB:P48059',
#       'PR:P48059',
#       'UMLS:C0256491']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['LIMS1',
#       'LIMS1 gene',
#       'LIMS1_HUMAN LIM and senescent cell antigen-like-containing domain protein 1 (sprot)',
#       'LIM and senescent cell antigen-like-containing domain protein 1 (human)',
#       'LIMS1 protein, human']}]},
#   'NCBIGene:7110': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'TMF1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7110',
#       'ENSEMBL:ENSG00000144747',
#       'HGNC:11870',
#       'OMIM:601126',
#       'UMLS:C1420778',
#       'UniProtKB:A0A024R370',
#       'UniProtKB:P82094',
#       'PR:P82094',
#       'UniProtKB:Q6PII6']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TMF1',
#       'TMF1 gene',
#       'A0A024R370_HUMAN TATA element modulatory factor 1, isoform CRA_a (trembl)',
#       'TMF1_HUMAN TATA element modulatory factor (sprot)',
#       'TATA element modulatory factor (human)',
#       'Q6PII6_HUMAN TMF1 protein (Fragment) (trembl)']}]},
#   'NCBIGene:9589': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'WTAP',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9589',
#       'ENSEMBL:ENSG00000146457',
#       'HGNC:16846',
#       'OMIM:605442',
#       'UMLS:C1424590',
#       'UniProtKB:A0A087X1R4',
#       'ENSEMBL:ENSP00000484404',
#       'ENSEMBL:ENSP00000484404.1',
#       'ENSEMBL:ENSP00000487338',
#       'ENSEMBL:ENSP00000487338.1',
#       'UniProtKB:Q15007',
#       'PR:Q15007',
#       'UMLS:C1432048']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['WTAP',
#       'WTAP gene',
#       'A0A087X1R4_HUMAN Pre-mRNA-splicing regulator WTAP (trembl)',
#       'FL2D_HUMAN Pre-mRNA-splicing regulator WTAP (sprot)',
#       'pre-mRNA-splicing regulator WTAP (human)',
#       'WTAP protein, human']}]},
#   'NCBIGene:29979': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'UBQLN1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:29979',
#       'ENSEMBL:ENSG00000135018',
#       'HGNC:12508',
#       'OMIM:605046',
#       'UMLS:C1421304',
#       'UniProtKB:A0A024R258',
#       'UniProtKB:Q9UMX0',
#       'PR:Q9UMX0']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['UBQLN1',
#       'UBQLN1 gene',
#       'A0A024R258_HUMAN Ubiquilin 1, isoform CRA_d (trembl)',
#       'UBQL1_HUMAN Ubiquilin-1 (sprot)',
#       'ubiquilin-1 (human)']}]},
#   'NCBIGene:29982': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'NRBF2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:29982',
#       'ENSEMBL:ENSG00000148572',
#       'HGNC:19692',
#       'OMIM:616477',
#       'UMLS:C1426338',
#       'UniProtKB:Q96F24',
#       'PR:Q96F24']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NRBF2',
#       'NRBF2 gene',
#       'NRBF2_HUMAN Nuclear receptor-binding factor 2 (sprot)',
#       'nuclear receptor-binding factor 2 (human)']}]},
#   'NCBIGene:9221': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'NOLC1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9221',
#       'ENSEMBL:ENSG00000166197',
#       'HGNC:15608',
#       'OMIM:602394',
#       'UMLS:C1423614',
#       'UniProtKB:B2RAU8',
#       'UniProtKB:Q14978',
#       'PR:Q14978',
#       'UniProtKB:Q96J17']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NOLC1',
#       'NOLC1 gene',
#       'B2RAU8_HUMAN cDNA, FLJ95131, highly similar to Homo sapiens nucleolar and coiled-body phosphoprotein 1 (NOLC1), mRNA (trembl)',
#       'NOLC1_HUMAN Nucleolar and coiled-body phosphoprotein 1 (sprot)',
#       'nucleolar and coiled-body phosphoprotein 1 (human)',
#       'Q96J17_HUMAN NOLC1 protein (trembl)']}]},
#   'NCBIGene:8036': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SHOC2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8036',
#       'ENSEMBL:ENSG00000108061',
#       'HGNC:15454',
#       'OMIM:602775',
#       'UMLS:C1423500',
#       'UniProtKB:Q9UQ13',
#       'PR:Q9UQ13',
#       'UMLS:C0676309']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SHOC2',
#       'SHOC2 gene',
#       'SHOC2_HUMAN Leucine-rich repeat protein SHOC-2 (sprot)',
#       'leucine-rich repeat protein SHOC-2 (human)',
#       'Leucine-Rich Repeat Protein SHOC-2, Human']}]},
#   'NCBIGene:5908': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RAP1B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5908',
#       'ENSEMBL:ENSG00000127314',
#       'HGNC:9857',
#       'OMIM:179530',
#       'UMLS:C1419266',
#       'UniProtKB:A0A024RB87',
#       'UniProtKB:B7ZAY2',
#       'UniProtKB:P61224',
#       'PR:P61224']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAP1B',
#       'RAP1B gene',
#       'A0A024RB87_HUMAN RAP1B, member of RAS oncogene family, isoform CRA_a (trembl)',
#       'B7ZAY2_HUMAN cDNA, FLJ79346, highly similar to Ras-related protein Rap-1b (trembl)',
#       'RAP1B_HUMAN Ras-related protein Rap-1b (sprot)',
#       'Ras-related protein Rap-1b (human)']}]},
#   'NCBIGene:6416': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'MAP2K4',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6416',
#       'ENSEMBL:ENSG00000065559',
#       'HGNC:6844',
#       'OMIM:601335',
#       'UMLS:C1417008',
#       'UniProtKB:P45985',
#       'PR:P45985']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MAP2K4',
#       'MAP2K4 gene',
#       'MP2K4_HUMAN Dual specificity mitogen-activated protein kinase kinase 4 (sprot)',
#       'dual specificity mitogen-activated protein kinase kinase 4 (human)']}]},
#   'NCBIGene:57532': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'NUFIP2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57532',
#       'ENSEMBL:ENSG00000108256',
#       'HGNC:17634',
#       'OMIM:609356',
#       'UMLS:C1826496',
#       'UniProtKB:Q7Z417',
#       'PR:Q7Z417']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NUFIP2',
#       'NUFIP2 gene',
#       'NUFP2_HUMAN FMR1-interacting protein NUFIP2 (sprot)',
#       'FMR1-interacting protein NUFIP2 (human)']}]},
#   'NCBIGene:117584': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RFFL',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:117584',
#       'ENSEMBL:ENSG00000092871',
#       'HGNC:24821',
#       'OMIM:609735',
#       'UMLS:C1826808',
#       'UniProtKB:Q8WZ73',
#       'PR:Q8WZ73']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RFFL',
#       'RFFL gene',
#       'RFFL_HUMAN E3 ubiquitin-protein ligase rififylin (sprot)',
#       'E3 ubiquitin-protein ligase rififylin (human)']}]},
#   'NCBIGene:56270': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'WDR45B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:56270',
#       'ENSEMBL:ENSG00000141580',
#       'HGNC:25072',
#       'OMIM:609226',
#       'UMLS:C1538089',
#       'UniProtKB:Q5MNZ6',
#       'PR:Q5MNZ6',
#       'ENSEMBL:ENSP00000376139',
#       'ENSEMBL:ENSP00000376139.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['WDR45B',
#       'WDR45B gene',
#       'WIPI3_HUMAN WD repeat domain phosphoinositide-interacting protein 3 (sprot)',
#       'WD repeat domain phosphoinositide-interacting protein 3 (human)']}]},
#   'NCBIGene:8774': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'NAPG',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8774',
#       'ENSEMBL:ENSG00000134265',
#       'HGNC:7642',
#       'OMIM:603216',
#       'UMLS:C1417600',
#       'UniProtKB:Q6FHY4',
#       'UniProtKB:Q99747',
#       'PR:Q99747']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NAPG',
#       'NAPG gene',
#       'Q6FHY4_HUMAN N-ethylmaleimide-sensitive factor attachment protein, gamma, isoform CRA_b (trembl)',
#       'SNAG_HUMAN Gamma-soluble NSF attachment protein (sprot)',
#       'gamma-soluble NSF attachment protein (human)']}]},
#   'NCBIGene:23673': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'STX12',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23673',
#       'ENSEMBL:ENSG00000117758',
#       'HGNC:11430',
#       'OMIM:606892',
#       'UMLS:C1420495',
#       'UniProtKB:Q86Y82',
#       'PR:Q86Y82',
#       'ENSEMBL:ENSP00000363054',
#       'ENSEMBL:ENSP00000363054.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['STX12',
#       'STX12 gene',
#       'STX12_HUMAN Syntaxin-12 (sprot)',
#       'syntaxin-12 (human)']}]},
#   'NCBIGene:51441': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'YTHDF2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:51441',
#       'ENSEMBL:ENSG00000198492',
#       'HGNC:31675',
#       'OMIM:610640',
#       'UMLS:C1538134',
#       'UniProtKB:Q9Y5A9',
#       'PR:Q9Y5A9',
#       'UMLS:C3273756']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YTHDF2',
#       'YTHDF2 gene',
#       'YTHD2_HUMAN YTH domain-containing family protein 2 (sprot)',
#       'YTH domain-containing family protein 2 (human)',
#       'YTH Domain Family Protein 2']}]},
#   'NCBIGene:23507': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'LRRC8B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23507',
#       'ENSEMBL:ENSG00000197147',
#       'HGNC:30692',
#       'OMIM:612888',
#       'UMLS:C1825877',
#       'UniProtKB:A0A384N5V6',
#       'UniProtKB:A0A7I2RK03',
#       'ENSEMBL:ENSP00000400704',
#       'ENSEMBL:ENSP00000400704.2',
#       'UniProtKB:Q6P9F7',
#       'PR:Q6P9F7',
#       'ENSEMBL:ENSP00000332674',
#       'ENSEMBL:ENSP00000332674.2',
#       'ENSEMBL:ENSP00000491377',
#       'ENSEMBL:ENSP00000491377.1',
#       'ENSEMBL:ENSP00000492151',
#       'ENSEMBL:ENSP00000492151.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['LRRC8B',
#       'LRRC8B gene',
#       'A0A384N5V6_HUMAN Epididymis secretory sperm binding protein (trembl)',
#       'A0A7I2RK03_HUMAN Volume-regulated anion channel subunit LRRC8B (trembl)',
#       'LRC8B_HUMAN Volume-regulated anion channel subunit LRRC8B (sprot)',
#       'volume-regulated anion channel subunit LRRC8B (human)']}]},
#   'NCBIGene:6884': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'TAF13',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6884',
#       'ENSEMBL:ENSG00000197780',
#       'HGNC:11546',
#       'OMIM:600774',
#       'UMLS:C1336563',
#       'UniProtKB:A0A024R089',
#       'UniProtKB:Q15543',
#       'PR:Q15543',
#       'ENSEMBL:ENSP00000355051',
#       'ENSEMBL:ENSP00000355051.4',
#       'UMLS:C0756346']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TAF13',
#       'TAF13 gene',
#       'A0A024R089_HUMAN TAF13 RNA polymerase II, TATA box binding protein (TBP)-associated factor, 18kDa, isoform CRA_a (trembl)',
#       'TAF13_HUMAN Transcription initiation factor TFIID subunit 13 (sprot)',
#       'transcription initiation factor TFIID subunit 13 (human)',
#       'TAF13 protein, human']}]},
#   'NCBIGene:261726': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'TIPRL',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:261726',
#       'ENSEMBL:ENSG00000143155',
#       'HGNC:30231',
#       'OMIM:611807',
#       'UMLS:C1823282',
#       'UniProtKB:O75663',
#       'PR:O75663']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TIPRL',
#       'TIPRL gene',
#       'TIPRL_HUMAN TIP41-like protein (sprot)',
#       'TIP41-like protein (human)']}]},
#   'NCBIGene:23215': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PRRC2C',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23215',
#       'ENSEMBL:ENSG00000117523',
#       'HGNC:24903',
#       'OMIM:617373',
#       'UMLS:C1538318',
#       'UniProtKB:E7EPN9',
#       'ENSEMBL:ENSP00000356716',
#       'ENSEMBL:ENSP00000356716.3',
#       'UniProtKB:Q9Y520',
#       'PR:Q9Y520']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PRRC2C',
#       'PRRC2C gene',
#       'E7EPN9_HUMAN Protein PRRC2C (trembl)',
#       'PRC2C_HUMAN Protein PRRC2C (sprot)',
#       'protein PRRC2C (human)']}]},
#   'NCBIGene:84919': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PPP1R15B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:84919',
#       'ENSEMBL:ENSG00000158615',
#       'HGNC:14951',
#       'OMIM:613257',
#       'UMLS:C1423081',
#       'UniProtKB:A0A8I5KSH1',
#       'ENSEMBL:ENSP00000508814',
#       'ENSEMBL:ENSP00000508814.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PPP1R15B',
#       'PPP1R15B gene',
#       'A0A8I5KSH1_HUMAN Protein phosphatase 1 regulatory subunit 15B (trembl)']}]},
#   'NCBIGene:5861': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RAB1A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5861',
#       'ENSEMBL:ENSG00000138069',
#       'HGNC:9758',
#       'OMIM:179508',
#       'UMLS:C1419187',
#       'UniProtKB:B7Z8M7',
#       'UniProtKB:P62820',
#       'PR:P62820',
#       'UniProtKB:Q5U0I6']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAB1A',
#       'RAB1A gene',
#       'B7Z8M7_HUMAN cDNA FLJ57768, highly similar to Ras-related protein Rab-1A (trembl)',
#       'RAB1A_HUMAN Ras-related protein Rab-1A (sprot)',
#       'Ras-related protein Rab-1A (human)',
#       'Q5U0I6_HUMAN H.sapiens ras-related Hrab1A protein (trembl)']}]},
#   'NCBIGene:65977': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PLEKHA3',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:65977',
#       'ENSEMBL:ENSG00000116095',
#       'HGNC:14338',
#       'OMIM:607774',
#       'UMLS:C1422575',
#       'UniProtKB:Q9HB20',
#       'PR:Q9HB20',
#       'ENSEMBL:ENSP00000234453',
#       'ENSEMBL:ENSP00000234453.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PLEKHA3',
#       'PLEKHA3 gene',
#       'PKHA3_HUMAN Pleckstrin homology domain-containing family A member 3 (sprot)',
#       'pleckstrin homology domain-containing family A member 3 (human)']}]},
#   'NCBIGene:6434': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'TRA2B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6434',
#       'ENSEMBL:ENSG00000136527',
#       'HGNC:10781',
#       'OMIM:602719',
#       'UMLS:C1419990',
#       'UniProtKB:P62995',
#       'PR:P62995']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TRA2B',
#       'TRA2B gene',
#       'TRA2B_HUMAN Transformer-2 protein homolog beta (sprot)',
#       'transformer-2 protein homolog beta (human)']}]},
#   'NCBIGene:4790': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'NFKB1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:4790',
#       'ENSEMBL:ENSG00000109320',
#       'HGNC:7794',
#       'OMIM:164011',
#       'UMLS:C1417708',
#       'UniProtKB:P19838',
#       'PR:P19838',
#       'UMLS:C1452413',
#       'UMLS:C2986465']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NFKB1',
#       'NFKB1 gene',
#       'NFKB1_HUMAN Nuclear factor NF-kappa-B p105 subunit (sprot)',
#       'nuclear factor NF-kappa-B p105 subunit (human)',
#       'NFKB1 protein, human',
#       'Nuclear Factor NF-kappa-B p105 Subunit']}]},
#   'NCBIGene:5868': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'RAB5A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5868',
#       'ENSEMBL:ENSG00000144566',
#       'HGNC:9783',
#       'OMIM:179512',
#       'UMLS:C1419212',
#       'UniProtKB:A0A024R2K1',
#       'UniProtKB:P20339',
#       'PR:P20339',
#       'UMLS:C5400795']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAB5A',
#       'RAB5A gene',
#       'A0A024R2K1_HUMAN RAB5A, member RAS oncogene family, isoform CRA_a (trembl)',
#       'RAB5A_HUMAN Ras-related protein Rab-5A (sprot)',
#       'Ras-related protein Rab-5A (human)',
#       'Ras-Related Protein Rab-5A']}]},
#   'NCBIGene:7871': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SLMAP',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7871',
#       'ENSEMBL:ENSG00000163681',
#       'HGNC:16643',
#       'OMIM:602701',
#       'UMLS:C1424461',
#       'UniProtKB:B7Z6C7',
#       'UniProtKB:B7Z964',
#       'UniProtKB:Q14BN4',
#       'PR:Q14BN4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLMAP',
#       'SLMAP gene',
#       'B7Z6C7_HUMAN cDNA FLJ54546, highly similar to Homo sapiens sarcolemma associated protein (SLMAP), mRNA (trembl)',
#       'B7Z964_HUMAN cDNA FLJ60222, highly similar to Homo sapiens sarcolemma associated protein (SLMAP), mRNA (trembl)',
#       'SLMAP_HUMAN Sarcolemmal membrane-associated protein (sprot)',
#       'sarcolemmal membrane-associated protein (human)']}]},
#   'NCBIGene:80218': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'NAA50',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:80218',
#       'ENSEMBL:ENSG00000121579',
#       'HGNC:29533',
#       'OMIM:610834',
#       'UMLS:C1826357',
#       'UniProtKB:E7EQ69',
#       'ENSEMBL:ENSP00000417837',
#       'ENSEMBL:ENSP00000417837.1',
#       'UniProtKB:Q9GZZ1',
#       'PR:Q9GZZ1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NAA50',
#       'NAA50 gene',
#       'E7EQ69_HUMAN N-alpha-acetyltransferase 50 (trembl)',
#       'NAA50_HUMAN N-alpha-acetyltransferase 50 (sprot)',
#       'N-alpha-acetyltransferase 50 (human)']}]},
#   'NCBIGene:55153': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'SDAD1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:55153',
#       'ENSEMBL:ENSG00000198301',
#       'HGNC:25537',
#       'UMLS:C1428499',
#       'UniProtKB:B4DT66',
#       'UniProtKB:E7EW05',
#       'ENSEMBL:ENSP00000379061',
#       'ENSEMBL:ENSP00000379061.4',
#       'UniProtKB:Q9NVU7',
#       'PR:Q9NVU7']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SDAD1',
#       'SDAD1 gene',
#       'B4DT66_HUMAN Protein SDA1 (trembl)',
#       'E7EW05_HUMAN Protein SDA1 (trembl)',
#       'SDA1_HUMAN Protein SDA1 homolog (sprot)',
#       'protein SDA1 homolog (human)']}]},
#   'NCBIGene:80155': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'NAA15',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:80155',
#       'ENSEMBL:ENSG00000164134',
#       'HGNC:30782',
#       'OMIM:608000',
#       'UMLS:C1538040',
#       'UniProtKB:A0A0B4J1W3',
#       'ENSEMBL:ENSP00000381920',
#       'ENSEMBL:ENSP00000381920.1',
#       'UniProtKB:B2RBE5',
#       'UniProtKB:Q9BXJ9',
#       'PR:Q9BXJ9']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NAA15',
#       'NAA15 gene',
#       'A0A0B4J1W3_HUMAN N-alpha-acetyltransferase 15, NatA auxiliary subunit (trembl)',
#       'B2RBE5_HUMAN cDNA, FLJ95468, highly similar to Homo sapiens transcriptional coactivator tubedown-100 (TBDN100),transcript variant 1, mRNA (trembl)',
#       'NAA15_HUMAN N-alpha-acetyltransferase 15, NatA auxiliary subunit (sprot)',
#       'N-alpha-acetyltransferase 15, NatA auxiliary subunit (human)']}]},
#   'NCBIGene:55003': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'PAK1IP1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:55003',
#       'ENSEMBL:ENSG00000111845',
#       'HGNC:20882',
#       'OMIM:607811',
#       'UMLS:C1427187',
#       'UniProtKB:A0A0S2Z5C3',
#       'UniProtKB:Q9NWT1',
#       'PR:Q9NWT1',
#       'ENSEMBL:ENSP00000368887',
#       'ENSEMBL:ENSP00000368887.3',
#       'ENSEMBL:ENSP00000496482',
#       'ENSEMBL:ENSP00000496482.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PAK1IP1',
#       'PAK1IP1 gene',
#       'A0A0S2Z5C3_HUMAN PAK1 interacting protein 1 isoform 1 (Fragment) (trembl)',
#       'PK1IP_HUMAN p21-activated protein kinase-interacting protein 1 (sprot)',
#       'p21-activated protein kinase-interacting protein 1 (human)']}]},
#   'NCBIGene:734': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'OSGIN2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:734',
#       'ENSEMBL:ENSG00000164823',
#       'HGNC:1355',
#       'OMIM:604598',
#       'UMLS:C1826518',
#       'UniProtKB:A0A024R9D5',
#       'UniProtKB:Q9Y236',
#       'PR:Q9Y236']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['OSGIN2',
#       'OSGIN2 gene',
#       'A0A024R9D5_HUMAN Chromosome 8 open reading frame 1, isoform CRA_a (trembl)',
#       'OSGI2_HUMAN Oxidative stress-induced growth inhibitor 2 (sprot)',
#       'oxidative stress-induced growth inhibitor 2 (human)']}]},
#   'NCBIGene:7534': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'YWHAZ',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7534',
#       'ENSEMBL:ENSG00000164924',
#       'HGNC:12855',
#       'OMIM:601288',
#       'UMLS:C1421564',
#       'UniProtKB:D0PNI1',
#       'UniProtKB:P63104',
#       'PR:P63104']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YWHAZ',
#       'YWHAZ gene',
#       'D0PNI1_HUMAN Epididymis luminal protein 4 (trembl)',
#       '1433Z_HUMAN 14-3-3 protein zeta/delta (sprot)',
#       '14-3-3 protein zeta/delta (human)']}]},
#   'NCBIGene:4928': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'NUP98',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:4928',
#       'ENSEMBL:ENSG00000110713',
#       'HGNC:8068',
#       'OMIM:601021',
#       'UMLS:C1334913',
#       'UniProtKB:P52948',
#       'PR:P52948',
#       'UMLS:C1143533',
#       'UMLS:C4522157']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NUP98',
#       'NUP98 gene',
#       'NUP98_HUMAN Nuclear pore complex protein Nup98-Nup96 (sprot)',
#       'nuclear pore complex protein Nup98-Nup96 (human)',
#       'NUP98 protein, human',
#       'Nuclear Pore Complex Protein Nup98-Nup96']}]},
#   'NCBIGene:64786': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'TBC1D15',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:64786',
#       'ENSEMBL:ENSG00000121749',
#       'HGNC:25694',
#       'OMIM:612662',
#       'UMLS:C1428511',
#       'UniProtKB:A8K8E1',
#       'UniProtKB:Q8TC07',
#       'PR:Q8TC07']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TBC1D15',
#       'TBC1D15 gene',
#       'A8K8E1_HUMAN TBC1 domain family, member 15, isoform CRA_d (trembl)',
#       'TBC15_HUMAN TBC1 domain family member 15 (sprot)',
#       'TBC1 domain family member 15 (human)']}]},
#   'NCBIGene:6996': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'TDG',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6996',
#       'ENSEMBL:ENSG00000139372',
#       'HGNC:11700',
#       'OMIM:601423',
#       'UMLS:C1442760',
#       'UniProtKB:B4DI29',
#       'UniProtKB:B4E127',
#       'ENSEMBL:ENSP00000445899',
#       'ENSEMBL:ENSP00000445899.1',
#       'UniProtKB:Q13569',
#       'PR:Q13569',
#       'ENSEMBL:ENSP00000376611',
#       'ENSEMBL:ENSP00000376611.3',
#       'UMLS:C4316851']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TDG',
#       'TDG gene',
#       'B4DI29_HUMAN cDNA FLJ60553, highly similar to G/T mismatch-specific thymine DNA glycosylase (trembl)',
#       'B4E127_HUMAN G/T mismatch-specific thymine DNA glycosylase (trembl)',
#       'TDG_HUMAN G/T mismatch-specific thymine DNA glycosylase (sprot)',
#       'G/T mismatch-specific thymine DNA glycosylase (human)',
#       'G/T Mismatch-Specific Thymine DNA Glycosylase, human']}]},
#   'NCBIGene:81631': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'MAP1LC3B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:81631',
#       'ENSEMBL:ENSG00000140941',
#       'HGNC:13352',
#       'OMIM:609604',
#       'UMLS:C1421946',
#       'UniProtKB:Q658J6',
#       'UniProtKB:Q9GZQ8',
#       'PR:Q9GZQ8',
#       'ENSEMBL:ENSP00000268607',
#       'ENSEMBL:ENSP00000268607.5',
#       'ENSEMBL:ENSP00000498476',
#       'ENSEMBL:ENSP00000498476.1',
#       'UMLS:C1311384']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MAP1LC3B',
#       'MAP1LC3B gene',
#       'Q658J6_HUMAN Microtubule-associated protein 1 light chain 3 beta, isoform CRA_c (trembl)',
#       'MLP3B_HUMAN Microtubule-associated proteins 1A/1B light chain 3B (sprot)',
#       'microtubule-associated proteins 1A/1B light chain 3B (human)',
#       'MAP1LC3B protein, human']}]},
#   'NCBIGene:54915': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'YTHDF1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:54915',
#       'ENSEMBL:ENSG00000149658',
#       'HGNC:15867',
#       'OMIM:616529',
#       'UMLS:C1538132',
#       'UniProtKB:Q9BYJ9',
#       'PR:Q9BYJ9']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YTHDF1',
#       'YTHDF1 gene',
#       'YTHD1_HUMAN YTH domain-containing family protein 1 (sprot)',
#       'YTH domain-containing family protein 1 (human)']}]},
#   'NCBIGene:27000': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'DNAJC2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:27000',
#       'ENSEMBL:ENSG00000105821',
#       'HGNC:13192',
#       'OMIM:605502',
#       'UMLS:C1421867',
#       'UniProtKB:Q99543',
#       'PR:Q99543']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['DNAJC2',
#       'DNAJC2 gene',
#       'DNJC2_HUMAN DnaJ homolog subfamily C member 2 (sprot)',
#       'DnaJ homolog subfamily C member 2 (human)']}]},
#   'NCBIGene:55500': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'ETNK1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:55500',
#       'ENSEMBL:ENSG00000139163',
#       'HGNC:24649',
#       'OMIM:609858',
#       'UMLS:C1539368',
#       'UniProtKB:Q86U68',
#       'ENSEMBL:ENSP00000334041',
#       'ENSEMBL:ENSP00000334041.4',
#       'UniProtKB:Q9HBU6',
#       'PR:Q9HBU6',
#       'UMLS:C1565603']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ETNK1',
#       'ETNK1 gene',
#       'Q86U68_HUMAN Ethanolamine kinase (trembl)',
#       'EKI1_HUMAN Ethanolamine kinase 1 (sprot)',
#       'ethanolamine kinase 1 (human)',
#       'ETNK1 protein, human']}]},
#   'NCBIGene:25948': {'categories': ['biolink:BiologicalEntity'],
#    'name': 'KBTBD2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:25948',
#       'ENSEMBL:ENSG00000170852',
#       'HGNC:21751',
#       'OMIM:619393',
#       'UMLS:C1427741',
#       'UniProtKB:A0A024RA38',
#       'UniProtKB:Q8IY47',
#       'PR:Q8IY47',
#       'ENSEMBL:ENSP00000302586',
#       'ENSEMBL:ENSP00000302586.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['KBTBD2',
#       'KBTBD2 gene',
#       'A0A024RA38_HUMAN Kelch repeat and BTB (POZ) domain containing 2 (trembl)',
# ...
#      'value': 'Liver'}]},
#   '1e2cbf9e68d0468253a53307bb339616': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:7534',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '5da69b1b228e522b6e52b6f7cb81e482': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:4928',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   'f83df53ff7c6e09d3ef29794f5002e12': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:64786',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '8e384c7848e6ff1090e80f26591374f3': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:6996',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '2c2103fe09318e6b36630b960d478408': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:81631',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '05cda8e4cb1174f649336ad969fa7e91': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:54915',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '2df07c27a1a0e83938d0ca6fe8c84f00': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:27000',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '62154b85dffba2fcdaf99bc6035afa0e': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:55500',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '96005de07139ed0de8a9b5ff6733c159': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:25948',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '8d1b811d32bf69929d650f76fde49af8': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:1540',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '66b6f18b2cfd8db9b7154b78e966e63a': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:829',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '6fbd988e642fd5a8f8e8f0e2b8f5eda9': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:54834',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '17c356196adba20a88aa7aeb777202d8': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:9125',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   'e12315d1fbc136953a6966b0ccfa3012': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:51719',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   'a9bac2c64e064fefc27c67ba608d4cdd': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:283635',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '16dcf225aedeb2621cd86840546298dc': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:85403',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '774df1239c5da09322ff6a06c25ecdd3': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:2117',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '68b51070b58a99b3b6c21477e4aabf75': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:6990',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '94f2fedd49b1c30c98ce35abdb11183d': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:23560',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '237647ff6838e52c06ba66401ebfdc26': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:84312',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '48c385c6b4cde7433358792c1788dfe8': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:1983',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '7d742f2e6e1472db4d8a0a9ed72fcfff': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:10294',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '95ab73cf5132c35f2ed95ac35d91f86c': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:1452',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '2ee8857cdfc052b97dc12a57870b0a7c': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:3192',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]},
#   '45dad52c242a6c06af274d16b3d85a7f': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:1977',
#    'attributes': [{'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': ['infores:biothings-explorer'],
#      'value_type_id': 'biolink:InformationResource'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}]}}}
